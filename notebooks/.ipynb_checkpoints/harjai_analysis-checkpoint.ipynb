# %% [markdown]
# # SF Data Project
# ## By Kavish Harjai
# ## Analysis

# %% [markdown]
# ### Synopsis
#
# The San Francisco Rent Ordinance created the San Francisco Rent Board in 1979. The Board receives petitions from the city's landlords and tenants. In some cases, the Tent Board will oversee a mediation/arbitration session between the complainant and the alleged wrongdoer.  The nature of the petition, of course, varies depending on whom the filing party is, but the Rent Board can only adjudicate issues that are covered in the rent ordinance.
#
# I was specifically interested in investigating tenant petitions. In a petition, a tenant can allege one or more complaint, including wrongful eviction, unfair rent increase, a decrease in housing services (necessary repairs and replacements), etc.
#
# The city of San Francisco keeps a CSV of the petitions sent to the Board going back to January 1997.
#
# https://data.sfgov.org/Housing-and-Buildings/Petitions-to-the-Rent-Board/6swy-cmkq
#
# The data is "wide," meaning each possible complaint is its own column, and each column contains boolean values: 'True' if the particular complaint is one of the reasons for the petition, and 'False' if not. In addition to those complaint columns, there are several columns important to this analysis, including:
#
# * petition_id: unique identifier for each petition
# * date_filed: when the petition was filed
# * filing_party: did a tenant or a landlord file the petition?
# * neighborhoods: in which neighborhood does the petitioner live?
#
# One thing that's critical to understand is that each row refers to one petition. But a single petition can include several complaints (according to the SF Rent Board website: "The tenant may combine more than one type of claim in a Tenant Petition").
#
# I will analyze petitions submitted by tenants from 2010 to present. I ask the following questions:
#
# * In which year did tenants file the most petitions?
# * What kinds of complaints are the most popular?
# * From which neighborhoods did most complaints arise? And how does the number of complaints compare to the population of renters in each neighborhood?
#
# This project is divided into two notebooks. One focused on data preparation and another focused on analysis. Both can be found in the notebooks subfolder. My findings are located in the analysis notebook.
#
# I prepare the analyze the data in order of the questions above.

# %%
import pandas as pd
from datetime import datetime as dt
import os
import numpy as np
import altair as alt

#pd.set_option('display.max_columns', None)
#Optional command to see all columns

#pd.set_option('display.max_rows', None)
#Optional command to see all rows

data_dir = os.environ["DATA_DIR"]
raw_data = data_dir + "/raw/"
processed_data = data_dir + '/processed/'
petitions_file = os.path.join(processed_data, 'tenant_petitions_2010.csv')

tenant_petitions = pd.read_csv(petitions_file, low_memory=False)

# %%
tenant_petitions.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17269 entries, 0 to 17268
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   petition_id          17269 non-null  object
#  1   date_filed           17269 non-null  object
#  2   Priority             17269 non-null  bool
#  3   appeal_id            0 non-null      float64
#  4   filing_party         17269 non-null  object
#  5   prop_i_petition      0 non-null      float64
#  6   Address              17269 non-null  object
#  7   petition_zip_code    17262 non-null  object
#  8   supervisor_district  17269 non-null  float64
#  9   neighborhoods        17269 non-null  object
#  10  shape                17269 non-null  object
#  11  year                 17269 non-null  int64
#  12  month                17269 non-null  int64
#  13  reason               17269 non-null  object
#  14  value                17269 non-null  bool
# dtypes: bool(2), float64(3), int64(2), object(8)
# memory usage: 1.7+ MB

# %% [markdown]
# #### Since I prepared the data in the previous notebook, there's not much to see here ^.

# %% [markdown]
# ### 1. In which year did tenants file the most petitions?
#
# In this portion of the analysis, we'll group by year and count each rows in each year.

# %%
pop_years = tenant_petitions.groupby('year').petition_id.count().reset_index().sort_values('petition_id', ascending=False)
pop_years
# Out:
#     year  petition_id
# 5   2015         1912
# 4   2014         1881
# 2   2012         1598
# 8   2018         1511
# 3   2013         1510
# 7   2017         1499
# 6   2016         1473
# 1   2011         1427
# 9   2019         1383
# 0   2010         1255
# 10  2020          950
# 11  2021          870

# %%
pop_years_chart = alt.Chart(pop_years).mark_bar().encode(
    x=alt.X('year:O', title='Year'),
    y=alt.Y('petition_id', title='Amount of Complaints'),
    tooltip=[alt.Tooltip('petition_id', title='Amount of Complaints')]
).properties(
    title='Complaints by Year',
    width=800,
    height=300
).configure_bar(
    opacity=0.8,
    color='gold'
)
pop_years_chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Finding 1:
# * More than 1,900 complaints were leveled at landlords in 2015, making it the year that saw the highest number of complaints. 2014 was not far behind, with just 30 fewer complaints. In 2014, there were several news reports about record-breaking rent prices for one-bedrooms in San Francisco. According to Business Insider, which cites an analysis conducted by real estate website Zumper, rent for a one-bedroom in 2014 rose 13.5% city-wide. In some neighborhoods, rent for a one-bedroom rose as much as 30%. It makes sense that increasing rent would lead to more complaints: Tenants might have been surprised by the amount they'd have to spend in 2014 versus 2013, and they might have seen a quality of apartment maintenance that didn't correspond with the new, higher rent they were paying.
#
# SOURCES: https://www.businessinsider.com/chart-shows-how-expensive-san-francisco-rent-became-in-2014-2014-12 ; https://sf.curbed.com/2014/4/14/10115060/are-you-sitting-down-sfs-median-rent-rate-is-3200-month
# * 2020 and 2021 saw the fewest amount of complaints. There are several factors that could explain why years characterized by financial strife and longer hours at home didn't correlate with more complaints from tenants. According to data from the California Policy Lab, San Francisco saw a decrease in population in 2020. That's the first time that's happened since 2016, when CA Policy Lab started collecting data. According to a SF Chronicle analysis of the data: "the number of Californians leaving the state for other parts of the country has increased, while the number of people moving into the state from the rest of the U.S. has decreased." Fewer people means less competition for apartments and lower rents. According to data from ApartmentsList cited by SFGate, overall rents in San Francisco dropped more than 26% between March 2020 and January 2021.
#
# SOURCES:
# https://www.capolicylab.org/pandemic-patterns-california-is-seeing-fewer-entrances-and-more-exits-updated/
# https://www.sfchronicle.com/projects/2021/california-bay-area-migration-maps/
# https://www.sfgate.com/realestate/article/Can-your-landlord-raise-the-rent-pandemic-16302349.php

# %% [markdown]
# ### 2. What kinds of complaints are the most popular?

# %%
pop_petitions = tenant_petitions.groupby('reason').petition_id.count().reset_index().sort_values('petition_id', ascending=False)
pop_petitions
# Out:
#                               reason  petition_id
# 2   tenant_decrease_housing_services         5789
# 13          tenant_wrongful_eviction         4457
# 7               tenant_rent_increase         2723
# 9                 tenant_section_six          813
# 1         tenant_capital_improvement          812
# 12     tenant_water_revenue_hardship          608
# 5                       tenant_other          491
# 3     tenant_failure_repair_maintain          384
# 0                 tenant_alt_dispute          365
# 6       tenant_passthrough_challenge          264
# 10           tenant_summary_petition          250
# 14         tenant_wrongful_severance          209
# 11        tenant_utility_passthrough           63
# 8               tenant_section_eight           25
# 4               tenant_hotel_visitor           16

# %%
alt.Chart(pop_petitions).mark_bar().encode(
    x=alt.X('reason', sort='-y', title='Complaint Type'),
    y=alt.Y('petition_id', title='Amount of Complaints'),
    tooltip=[alt.Tooltip('petition_id', title='Amount of Complaints')]
).properties(
    title='Top Complaints',
    width=800,
    height=300
).configure_bar(
    opacity=0.8,
    color='green'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Finding 2:
#
# * The most popular tenant complaint is a decrease in housing services. This means the tenant alleges their landlord decreased necessary maintenance, including repairs and painting, without decreasing their base rent. Petitions alleging a decrease in housing services are essentially pleas to the Rent Board to compel the landlord to decrease the tenant's rent. In order for that to happen, the tenant must prove that they brought the issue to the landlord and the landlord did not change their practices.
# * The other two prominent types of complaints were those that alleged a wrongful eviction or unlawful rent increase. It's worth noting that while the Rent Board will investigate complaints alleging a wrongful eviction, it cannot decide whether the eviction is legal or not—that's up to the court.

# %% [markdown]
# #### To dig into this finding, I will see how the top three complaints changed over time.

# %%
three_most_popular = tenant_petitions[
    (tenant_petitions['reason'] == 'tenant_decrease_housing_services') |
    (tenant_petitions['reason'] =='tenant_rent_increase')|
    (tenant_petitions['reason'] =='tenant_wrongful_eviction')
]

# %%
most_pop_by_year = three_most_popular.groupby(
    ["reason", "year"]
).petition_id.count().reset_index()

# %%
most_pop_by_year_chart = alt.Chart(most_pop_by_year).mark_line().encode(
    x=alt.X('year:O', title='Year'),
    y=alt.Y('petition_id', title='Amount of Complaints'),
    color=alt.Color('reason', title='Complaint Type'),
    strokeDash='reason',
    tooltip=['year', 'petition_id', 'reason']
).properties(
    title='Top Three Complaints Over Time',
    width=800,
    height=300
).interactive()

most_pop_by_year_chart.configure_legend(
    strokeColor='gray',
    fillColor='#FFFFF',
    padding=10,
    cornerRadius=0,
)
# Out:
# alt.Chart(...)

# %% [markdown]
# #### This chart is helpful, but I think it will be even more helpful to see how these three complaints changed over time along with the trend of all complaints, which I showed earlier in the pop_years_chart.
#
# The below cell demonstrates how to create a layered chart in altair. I copied my code for the chart under question one (pop_years_chart) and named it 'base,' since it will be the background chart. Next, I copied my code for the chart immediately above this text (most_pop_by_year) and named it 'second_layer,' since it will be in the foreground.
#
# I combine the two charts using the alt.layer() function.

# %%
base = alt.Chart(pop_years).encode(
    x=alt.X('year:O', title='Year'),
    y=alt.Y('petition_id', title='Amount of Complaints')
)

second_layer = alt.Chart(most_pop_by_year).encode(
    x=alt.X('year:O', title='Year'),
    y=alt.Y('petition_id', title='Amount of Complaints'),
    color=alt.Color('reason', title='Complaint Type'),
    strokeDash='reason',
    tooltip=['year', 'petition_id', 'reason']
)

alt.layer(
    base.mark_bar().encode(),
    second_layer.mark_line().encode()
).properties(
    title='Top Three Complaints Over Time Versus All Complaints',
    width=800,
    height=300
).configure_bar(
    opacity=0.4,
    color='gold'
)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ### Finding 2 (cont.):
# * It's interesting that complaints alleging an unlawful rent increase and wrongful eviction decreased since 2015, mirroring the pattern of the decrease in *all complaints* since 2015, but the complaints alleging a decrease in housing services remained steady. This raises a few questions that could guide further reporting on the trend: Could the stay-at-home orders be responsible, in that people were spending more time at their homes and demanded/noticed housing services? Did complaints for housing services consistently come from the same source neighborhood? Are there any similarities between the buildings where complaints about a decrease in housing services came from? Like a similar owner?

# %% [markdown]
# ### 3. From which neighborhoods did most complaints arise? And how does the number of complaints compare to the population of renters in each neighborhood?

# %% [markdown]
# In this portion of the analysis, I'll group by neighborhoods and count the number of complaints.

# %%
pop_neighborhoods = tenant_petitions.groupby('neighborhoods').petition_id.count().reset_index().sort_values('petition_id', ascending=False)

# %%
pop_neighborhoods.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 41 entries, 18 to 29
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighborhoods  41 non-null     object
#  1   petition_id    41 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 984.0+ bytes

# %%
alt.Chart(pop_neighborhoods).mark_bar().encode(
    x=alt.X('neighborhoods', sort='-y', title='Neighborhood'),
    y=alt.Y('petition_id', title='Amount of Complaints'),
    tooltip=[alt.Tooltip('petition_id', title='Amount of Complaints')]
).properties(
    title='Amount of Complaints by Neighborhood',
    width=800,
    height=300
).configure_bar(
    opacity=0.8,
    color='pink'
)
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Finding 3:
# * The main takeaway from the above graph is that most tenant complaints since 2010 came from people living in the Mission. Tenderloin and Sunset/Parkside saw the second and third most complaints.

# %% [markdown]
# #### The raw number of complaints per neighborhood is good, but it's not normalized. That means the above graph doesn't take into account how many people live in any given neighorhood, and even more specifically, how many people in that neighborhood rent, rather than own, their home. In the last bit of analysis that follows, I use additional data from the city of San Francisco and the American Community Survey five-year estimates to find a rate of complaints per every 100 renters in each neighborhood in two different years: 2015 and 2019.
#
# #### Broadly, these are the next steps:
# 1. Bring in 2010 census tracts assigned to SF neighborhoods
# 2. Use Census API to get renters per tract in 2015 and 2019
# 3. Merge dataframes from steps one and two, resulting in two new dataframes: merged_2015 and merged_2019
# 4. Add up renters by neighborhod in 2015 and 2019, and sum the complaints by neighborhood in 2015 and 2019 using my original dataframe
# 5. Merge the group-by objects in step 4, and find rate of complaints per 100 renters in the neighborhood

# %% [markdown]
# #### 1. Bring in 2010 census tracts assigned to SF neighborhoods
#
# San Francisco has data categorizing 2010 census tracts by neighborhood: https://data.sfgov.org/Geographic-Locations-and-Boundaries/Analysis-Neighborhoods-2010-census-tracts-assigned/bwbp-wk3r
#
# I pull that data in here using the relative path I defined at the beginning of this notebook. I drop columns that are not important to this analysis, including the shape information used to create a map. I retain and rename columns regarding the tract number and what neighborhood it corresponds to.

# %%
tracts_file = os.path.join(processed_data, 'sf_tracts_neighborhood_EDITED.csv')
tracts_file = pd.read_csv(tracts_file, low_memory=False, dtype=str)

# %%
tracts_file = tracts_file.drop(columns=['the_geom', 
                                        'GEOID', 
                                        'SHAPE_AREA', 
                                        'SHAPE_LEN',
                                       'Unnamed: 6',
                                       'Unnamed: 7']
                              ).rename(columns={'NHOOD': 'neighborhoods',
                                                'TRACTCE10': 'tract'})

# %%
tracts_file.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighborhoods  196 non-null    object
#  1   tract          196 non-null    object
# dtypes: object(2)
# memory usage: 3.5+ KB

# %%
tracts_file
# Out:
#                       neighborhoods   tract
# 0             Bayview Hunters Point  061200
# 1             Bayview Hunters Point  023003
# 2             Bayview Hunters Point  023001
# 3             Bayview Hunters Point  023400
# 4             Bayview Hunters Point  023300
# 5             Bayview Hunters Point  023102
# 6             Bayview Hunters Point  023103
# 7             Bayview Hunters Point  023200
# 8             Bayview Hunters Point  061000
# 9             Bayview Hunters Point  980600
# 10            Bayview Hunters Point  980900
# 11            Bayview Hunters Point  980900
# 12                   Bernal Heights  025401
# 13                   Bernal Heights  025200
# 14                   Bernal Heights  025402
# 15                   Bernal Heights  025403
# 16                   Bernal Heights  025300
# 17                   Bernal Heights  025100
# 18              Castro/Upper Market  020300
# 19              Castro/Upper Market  016900
# 20              Castro/Upper Market  020401
# 21              Castro/Upper Market  020600
# 22              Castro/Upper Market  020500
# 23              Castro/Upper Market  017000
# 24                        Chinatown  011300
# 25                        Chinatown  010700
# 26                        Chinatown  011800
# 27                        Chinatown  061100
# 28                        Excelsior  026303
# 29                        Excelsior  026004
# 30                        Excelsior  026302
# 31                        Excelsior  026003
# 32                        Excelsior  026301
# 33                        Excelsior  026001
# 34                        Excelsior  026002
# 35                        Excelsior  025600
# 36   Financial District/South Beach  011700
# 37   Financial District/South Beach  010500
# 38   Financial District/South Beach  061500
# 39                        Glen Park  021800
# 40                        Glen Park  021700
# 41                 Golden Gate Park  980300
# 42                   Haight Ashbury  016600
# 43                   Haight Ashbury  017102
# 44                   Haight Ashbury  017101
# 45                   Haight Ashbury  016700
# 46                     Hayes Valley  016400
# 47                     Hayes Valley  016802
# 48                     Hayes Valley  016200
# 49                     Hayes Valley  016300
# 50                     Hayes Valley  016801
# 51                   Inner Richmond  045200
# 52                   Inner Richmond  040200
# 53                   Inner Richmond  040100
# 54                   Inner Richmond  045100
# 55                     Inner Sunset  030302
# 56                     Inner Sunset  030301
# 57                     Inner Sunset  030102
# 58                     Inner Sunset  030101
# 59                     Inner Sunset  030202
# 60                     Inner Sunset  030201
# 61                        Japantown  015500
# 62                        Lakeshore  033204
# 63                        Lakeshore  033203
# 64                        Lakeshore  033201
# 65                        Lakeshore  060400
# 66                     Lincoln Park  980200
# 67                Lone Mountain/USF  016500
# 68                Lone Mountain/USF  015700
# 69                Lone Mountain/USF  015600
# 70                           Marina  012601
# 71                           Marina  012902
# 72                           Marina  013000
# 73                           Marina  012800
# 74                           Marina  012901
# 75                           Marina  012700
# 76                           Marina  012602
# 77                     McLaren Park  980501
# 78                          Mission  020700
# 79                          Mission  020900
# 80                          Mission  020100
# 81                          Mission  022903
# 82                          Mission  022802
# 83                          Mission  022901
# 84                          Mission  022801
# 85                          Mission  021000
# 86                          Mission  020800
# 87                          Mission  020200
# 88                          Mission  017700
# 89                          Mission  022902
# 90                          Mission  022803
# 91                      Mission Bay  060700
# 92                         Nob Hill  012100
# 93                         Nob Hill  012000
# 94                         Nob Hill  011200
# 95                         Nob Hill  011100
# 96                         Nob Hill  010800
# 97                         Nob Hill  011902
# 98                         Nob Hill  011901
# 99                       Noe Valley  021400
# 100                      Noe Valley  021300
# 101                      Noe Valley  021100
# 102                      Noe Valley  021600
# 103                      Noe Valley  021500
# 104                      Noe Valley  021200
# 105                     North Beach  010600
# 106                     North Beach  010400
# 107                     North Beach  010100
# 108      Oceanview/Merced/Ingleside  031301
# 109      Oceanview/Merced/Ingleside  031202
# 110      Oceanview/Merced/Ingleside  031302
# 111      Oceanview/Merced/Ingleside  031400
# 112      Oceanview/Merced/Ingleside  031201
# 113                   Outer Mission  026200
# 114                   Outer Mission  026100
# 115                   Outer Mission  025500
# 116                  Outer Richmond  047802
# 117                  Outer Richmond  042601
# 118                  Outer Richmond  047801
# 119                  Outer Richmond  042602
# 120                  Outer Richmond  047902
# 121                  Outer Richmond  047702
# 122                  Outer Richmond  047600
# 123                  Outer Richmond  042700
# 124                  Outer Richmond  047901
# 125                  Outer Richmond  047701
# 126                 Pacific Heights  015300
# 127                 Pacific Heights  013400
# 128                 Pacific Heights  013200
# 129                 Pacific Heights  013102
# 130                 Pacific Heights  015200
# 131                 Pacific Heights  013500
# 132                 Pacific Heights  013101
# 133                         Portola  025900
# 134                         Portola  025800
# 135                         Portola  025702
# 136                         Portola  025701
# 137                    Potrero Hill  022704
# 138                    Potrero Hill  061400
# 139                    Potrero Hill  022702
# 140                    Potrero Hill  022600
# 141                        Presidio  060100
# 142                Presidio Heights  015400
# 143                Presidio Heights  013300
# 144                    Russian Hill  010900
# 145                    Russian Hill  011000
# 146                    Russian Hill  010300
# 147                    Russian Hill  010200
# 148                        Seacliff  042800
# 149                 South of Market  017802
# 150                 South of Market  017801
# 151                 South of Market  018000
# 152                 South of Market  017601
# 153                 Sunset/Parkside  032902
# 154                 Sunset/Parkside  032901
# 155                 Sunset/Parkside  032801
# 156                 Sunset/Parkside  032802
# 157                 Sunset/Parkside  032602
# 158                 Sunset/Parkside  032601
# 159                 Sunset/Parkside  033000
# 160                 Sunset/Parkside  035400
# 161                 Sunset/Parkside  035201
# 162                 Sunset/Parkside  035100
# 163                 Sunset/Parkside  033100
# 164                 Sunset/Parkside  035300
# 165                 Sunset/Parkside  035202
# 166                 Sunset/Parkside  032700
# 167                      Tenderloin  012502
# 168                      Tenderloin  012302
# 169                      Tenderloin  012301
# 170                      Tenderloin  012401
# 171                      Tenderloin  012201
# 172                      Tenderloin  012202
# 173                      Tenderloin  012501
# 174                      Tenderloin  012402
# 175                 Treasure Island  017902
# 176                      Twin Peaks  030500
# 177                      Twin Peaks  020402
# 178               Visitacion Valley  060502
# 179               Visitacion Valley  026403
# 180               Visitacion Valley  026401
# 181               Visitacion Valley  026402
# 182               Visitacion Valley  026404
# 183              West of Twin Peaks  031100
# 184              West of Twin Peaks  031000
# 185              West of Twin Peaks  030900
# 186              West of Twin Peaks  030700
# 187              West of Twin Peaks  030600
# 188              West of Twin Peaks  030800
# 189              West of Twin Peaks  030400
# 190                Western Addition  016100
# 191                Western Addition  015900
# 192                Western Addition  015100
# 193                Western Addition  015802
# 194                Western Addition  016000
# 195                Western Addition  015801
# 196                             NaN     NaN
# 197                             NaN     NaN
# 198                             NaN     NaN
# 199                             NaN     NaN
# 200                             NaN     NaN
# 201                             NaN     NaN
# 202                             NaN     NaN
# 203                             NaN     NaN
# 204                             NaN     NaN
# 205                             NaN     NaN
# 206                             NaN     NaN
# 207                             NaN     NaN
# 208                             NaN     NaN
# 209                             NaN     NaN
# 210                             NaN     NaN
# 211                             NaN     NaN
# 212                             NaN     NaN
# 213                             NaN     NaN

# %% [markdown]
# Here I notice that there are multiple rows that are N/A. I know from looking at the CSV that these are the rows dedicated to shape information, so I will drop them using their index.

# %%
tracts_file.drop(tracts_file.index[196:214], axis=0, inplace=True)

# %%
tracts_file
# Out:
#                       neighborhoods   tract
# 0             Bayview Hunters Point  061200
# 1             Bayview Hunters Point  023003
# 2             Bayview Hunters Point  023001
# 3             Bayview Hunters Point  023400
# 4             Bayview Hunters Point  023300
# 5             Bayview Hunters Point  023102
# 6             Bayview Hunters Point  023103
# 7             Bayview Hunters Point  023200
# 8             Bayview Hunters Point  061000
# 9             Bayview Hunters Point  980600
# 10            Bayview Hunters Point  980900
# 11            Bayview Hunters Point  980900
# 12                   Bernal Heights  025401
# 13                   Bernal Heights  025200
# 14                   Bernal Heights  025402
# 15                   Bernal Heights  025403
# 16                   Bernal Heights  025300
# 17                   Bernal Heights  025100
# 18              Castro/Upper Market  020300
# 19              Castro/Upper Market  016900
# 20              Castro/Upper Market  020401
# 21              Castro/Upper Market  020600
# 22              Castro/Upper Market  020500
# 23              Castro/Upper Market  017000
# 24                        Chinatown  011300
# 25                        Chinatown  010700
# 26                        Chinatown  011800
# 27                        Chinatown  061100
# 28                        Excelsior  026303
# 29                        Excelsior  026004
# 30                        Excelsior  026302
# 31                        Excelsior  026003
# 32                        Excelsior  026301
# 33                        Excelsior  026001
# 34                        Excelsior  026002
# 35                        Excelsior  025600
# 36   Financial District/South Beach  011700
# 37   Financial District/South Beach  010500
# 38   Financial District/South Beach  061500
# 39                        Glen Park  021800
# 40                        Glen Park  021700
# 41                 Golden Gate Park  980300
# 42                   Haight Ashbury  016600
# 43                   Haight Ashbury  017102
# 44                   Haight Ashbury  017101
# 45                   Haight Ashbury  016700
# 46                     Hayes Valley  016400
# 47                     Hayes Valley  016802
# 48                     Hayes Valley  016200
# 49                     Hayes Valley  016300
# 50                     Hayes Valley  016801
# 51                   Inner Richmond  045200
# 52                   Inner Richmond  040200
# 53                   Inner Richmond  040100
# 54                   Inner Richmond  045100
# 55                     Inner Sunset  030302
# 56                     Inner Sunset  030301
# 57                     Inner Sunset  030102
# 58                     Inner Sunset  030101
# 59                     Inner Sunset  030202
# 60                     Inner Sunset  030201
# 61                        Japantown  015500
# 62                        Lakeshore  033204
# 63                        Lakeshore  033203
# 64                        Lakeshore  033201
# 65                        Lakeshore  060400
# 66                     Lincoln Park  980200
# 67                Lone Mountain/USF  016500
# 68                Lone Mountain/USF  015700
# 69                Lone Mountain/USF  015600
# 70                           Marina  012601
# 71                           Marina  012902
# 72                           Marina  013000
# 73                           Marina  012800
# 74                           Marina  012901
# 75                           Marina  012700
# 76                           Marina  012602
# 77                     McLaren Park  980501
# 78                          Mission  020700
# 79                          Mission  020900
# 80                          Mission  020100
# 81                          Mission  022903
# 82                          Mission  022802
# 83                          Mission  022901
# 84                          Mission  022801
# 85                          Mission  021000
# 86                          Mission  020800
# 87                          Mission  020200
# 88                          Mission  017700
# 89                          Mission  022902
# 90                          Mission  022803
# 91                      Mission Bay  060700
# 92                         Nob Hill  012100
# 93                         Nob Hill  012000
# 94                         Nob Hill  011200
# 95                         Nob Hill  011100
# 96                         Nob Hill  010800
# 97                         Nob Hill  011902
# 98                         Nob Hill  011901
# 99                       Noe Valley  021400
# 100                      Noe Valley  021300
# 101                      Noe Valley  021100
# 102                      Noe Valley  021600
# 103                      Noe Valley  021500
# 104                      Noe Valley  021200
# 105                     North Beach  010600
# 106                     North Beach  010400
# 107                     North Beach  010100
# 108      Oceanview/Merced/Ingleside  031301
# 109      Oceanview/Merced/Ingleside  031202
# 110      Oceanview/Merced/Ingleside  031302
# 111      Oceanview/Merced/Ingleside  031400
# 112      Oceanview/Merced/Ingleside  031201
# 113                   Outer Mission  026200
# 114                   Outer Mission  026100
# 115                   Outer Mission  025500
# 116                  Outer Richmond  047802
# 117                  Outer Richmond  042601
# 118                  Outer Richmond  047801
# 119                  Outer Richmond  042602
# 120                  Outer Richmond  047902
# 121                  Outer Richmond  047702
# 122                  Outer Richmond  047600
# 123                  Outer Richmond  042700
# 124                  Outer Richmond  047901
# 125                  Outer Richmond  047701
# 126                 Pacific Heights  015300
# 127                 Pacific Heights  013400
# 128                 Pacific Heights  013200
# 129                 Pacific Heights  013102
# 130                 Pacific Heights  015200
# 131                 Pacific Heights  013500
# 132                 Pacific Heights  013101
# 133                         Portola  025900
# 134                         Portola  025800
# 135                         Portola  025702
# 136                         Portola  025701
# 137                    Potrero Hill  022704
# 138                    Potrero Hill  061400
# 139                    Potrero Hill  022702
# 140                    Potrero Hill  022600
# 141                        Presidio  060100
# 142                Presidio Heights  015400
# 143                Presidio Heights  013300
# 144                    Russian Hill  010900
# 145                    Russian Hill  011000
# 146                    Russian Hill  010300
# 147                    Russian Hill  010200
# 148                        Seacliff  042800
# 149                 South of Market  017802
# 150                 South of Market  017801
# 151                 South of Market  018000
# 152                 South of Market  017601
# 153                 Sunset/Parkside  032902
# 154                 Sunset/Parkside  032901
# 155                 Sunset/Parkside  032801
# 156                 Sunset/Parkside  032802
# 157                 Sunset/Parkside  032602
# 158                 Sunset/Parkside  032601
# 159                 Sunset/Parkside  033000
# 160                 Sunset/Parkside  035400
# 161                 Sunset/Parkside  035201
# 162                 Sunset/Parkside  035100
# 163                 Sunset/Parkside  033100
# 164                 Sunset/Parkside  035300
# 165                 Sunset/Parkside  035202
# 166                 Sunset/Parkside  032700
# 167                      Tenderloin  012502
# 168                      Tenderloin  012302
# 169                      Tenderloin  012301
# 170                      Tenderloin  012401
# 171                      Tenderloin  012201
# 172                      Tenderloin  012202
# 173                      Tenderloin  012501
# 174                      Tenderloin  012402
# 175                 Treasure Island  017902
# 176                      Twin Peaks  030500
# 177                      Twin Peaks  020402
# 178               Visitacion Valley  060502
# 179               Visitacion Valley  026403
# 180               Visitacion Valley  026401
# 181               Visitacion Valley  026402
# 182               Visitacion Valley  026404
# 183              West of Twin Peaks  031100
# 184              West of Twin Peaks  031000
# 185              West of Twin Peaks  030900
# 186              West of Twin Peaks  030700
# 187              West of Twin Peaks  030600
# 188              West of Twin Peaks  030800
# 189              West of Twin Peaks  030400
# 190                Western Addition  016100
# 191                Western Addition  015900
# 192                Western Addition  015100
# 193                Western Addition  015802
# 194                Western Addition  016000
# 195                Western Addition  015801

# %% [markdown]
# #### 2. Use Census API to get renters per tract in 2015 and 2019
#
# To work with the Census API, I need the requests library.

# %%
import requests
from pprint import pprint

# %% [markdown]
# I'll create a function for the Census API call.

# %%
def get_ACS(year):
    dsource = 'acs'
    dname = 'acs5'
    base_url = f'https://api.census.gov/data/{year}/{dsource}/{dname}'
    chart = 'B25003'
    state = '06'
    county = '075'
    api_key = os.environ["CENSUS_API_KEY"]
    data_url = f'{base_url}?get=group({chart})&for=tract:*&in=state:{state}&in=county:{county}&key={api_key}'
    response=requests.get(data_url)
    json=response.json()
    return json

# %% [markdown]
# Ok, let's breakdown the above API call so that future Kavish or someone else using this script can figure out how to change the fields to get the data they need.
#
# * The function takes a year as an argument.
# * dsource is the Census product you need information from. I'm using the ACS but one could use this to specify that they want information from the decennial census, for example.
# * dname is the name of the survey I want: ACS five year estimates.
# * **The above forms the base url.**
# * chart refers to the specific table I want. In this case, table B25003 is called 'Tenure' and lists the amount of owner and rent-occupied units in the specified geography.
# * state and county are self-explanatory. Here, 06 = California and 075 = San Francisco County.
# * My api_key is stored on my computer.
# * **The base url plus the extra chart and geographical specifications forms the final url that tells the API exactly what data we want.**
#
# Pro-tip: If you want to check out what kind of data you can expect to get before sending the API call, you can put the data_url minus the API key in your browser. For example: https://api.census.gov/data/2015/acs/acs5?get=group(B25003)&for=tract:*&in=state:06&in=county:075
#
# Note: The url construction here will return all tracts in the specified county (hence 'for=tract:(asterisk)'). If you wanted a specific tract, or a completely different geography altogether, check out the examples of how to construct the url here: https://api.census.gov/data/2015/acs/acs5/examples.html
#
# #### Alrighty, let's use the function to call data for 2015 and 2019.

# %%
renters_per_tract_2015 = get_ACS(2015)
renters_2015 =pd.DataFrame(renters_per_tract_2015[1:], columns=renters_per_tract_2015[0] #first argument specified rows, second specifies columns
                         ).rename(columns={"GEO_ID":"geo_id",
                                           "B25003_001E":"total",
                                           "B25003_001M":"total_moe", #moe is margin of error
                                           "B25003_002E":"owner",
                                           "B25003_002M":"owner_moe",
                                           "B25003_003E":"renter",
                                          "B25003_003M":"renter_moe"} #these readable column names came from investigating the chart on data.census.gov
                                 ).drop(columns=['B25003_001EA', 
                                                 'B25003_001MA', 
                                                 'B25003_002EA',
                                                 'B25003_002MA',
                                                 'B25003_003EA',
                                                 'B25003_003MA',
                                                 'geo_id',]
                                       )

# %%
renters_2015
# Out:
#     total total_moe owner owner_moe renter renter_moe  \
# 0    1240        72   680       110    560        131
# 1    2096       108   593       126   1503        158
# 2    2689       112  1549       203   1140        212
# 3    1533       106   782        95    751        133
# 4    1062        57   723        82    339         93
# 5    2109       133   459       112   1650        144
# 6    2589        69  1777       189    812        185
# 7    2197       116   673       153   1524        173
# 8    1872       126   236        94   1636        134
# 9    1545       101   934       116    611        126
# 10   1716        89   475        87   1241        108
# 11   2756       160   666       146   2090        192
# 12   2663       125   414       135   2249        192
# 13   1879        95   832       132   1047        137
# 14   1406        71   754       122    652        123
# 15   1198        81   702       104    496        103
# 16   2426       144   200        80   2226        158
# 17   1647        94   166        61   1481        110
# 18   1600       105   390        82   1210        116
# 19   2155       138  1351       189    804        188
# 20   2049       114   346        97   1703        141
# 21   1818       142   545       115   1273        141
# 22   2079       105   650       159   1429        170
# 23   1500       133   355        82   1145        139
# 24   2632       151   710       156   1922        217
# 25   1887        79   326        96   1561        121
# 26   7177       512  2729       514   4448        531
# 27   1432        91   328        79   1104         94
# 28   2615       171   826       175   1789        202
# 29   2524       137   432       108   2092        159
# 30   1492        56  1276        93    216         80
# 31   2464       118   711       167   1753        174
# 32   2030       171   507       136   1523        183
# 33   2617       129   473       211   2144        213
# 34   2874       158   826       153   2048        214
# 35   2557       183   795       159   1762        239
# 36   2734        58  2005       202    729        214
# 37   1626        81  1188       132    438        105
# 38    632        38   344        54    288         53
# 39   1506        91   809       102    697        120
# 40   2165       144   726       135   1439        178
# 41   2928       111  1011       178   1917        174
# 42   2000        68  1107       128    893        123
# 43    905        86   590        70    315         93
# 44   1786       101   673       104   1113        140
# 45   1244        95   566       100    678        120
# 46   1377        47   778        96    599         93
# 47   1521        62   933       126    588        120
# 48   1244        74   735       111    509        106
# 49   1008        63   740        78    268         79
# 50   2462       129  1542       171    920        168
# 51   2156       168   464       143   1692        214
# 52   1667       104   897       125    770        147
# 53   2625        99   618       160   2007        176
# 54   1591       101   817       109    774        127
# 55   1410        80  1002       106    408        105
# 56   1149       119   581       124    568        110
# 57   1891        92  1137       119    754        116
# 58    885        50   587        60    298         62
# 59   1312        81  1040       112    272         91
# 60   1509       120   359        84   1150        133
# 61   1837       104   101        51   1736        109
# 62   2931       121   110        61   2821        132
# 63   1616       103    37        18   1579        106
# 64   1300       140     9        14   1291        141
# 65   1796       139     9        13   1787        140
# 66   2548       213     0        12   2548        213
# 67   2252       165   202       122   2050        190
# 68   2272       194    73        54   2199        211
# 69   2229       133    20        32   2209        135
# 70   1503       109   217        60   1286        123
# 71   1712        83   377        91   1335        101
# 72   1473       117   378        92   1095        135
# 73   2084       130   550       170   1534        189
# 74   2474       125   457       138   2017        166
# 75   1668        85   338        86   1330        117
# 76   1703       104   446       102   1257        131
# 77   1542       108   256        85   1286        131
# 78   1639       121   296       119   1343        123
# 79   1595       174   323        98   1272        162
# 80   1814        85   659        87   1155        112
# 81   1712        76   561        90   1151        114
# 82   2248       142   418       100   1830        149
# 83   1639       132   473        98   1166        123
# 84   1582       145   371        79   1211        121
# 85   1517        98   181        60   1336        106
# 86   2491       126   601       147   1890        176
# 87    756        53   116        52    640         73
# 88   1011        55   359        73    652         80
# 89   1939        94   802       105   1137        124
# 90   1039        92    62        39    977         94
# 91   1478        60  1046       130    432        130
# 92   1398        65   892       132    506        123
# 93   4107       287   431       131   3676        306
# 94   2910       227   597       138   2313        266
# 95   2578       153  1049       192   1529        220
# 96   1823        98   250        70   1573        100
# 97   1868        59  1090       139    778        119
# 98    868        68   432        61    436         73
# 99   1547        82   520        85   1027        120
# 100  1340        62   982        87    358         82
# 101  2071       145  1142       148    929        164
# 102  1342       116   613       103    729        122
# 103  2580       133  1137       188   1443        191
# 104  1610        86   552       111   1058        117
# 105  2427       166   502       128   1925        202
# 106   624        88     0        12    624         88
# 107  1665        91   891        95    774        117
# 108  1843        82  1219       135    624        129
# 109   639        51   166        45    473         56
# 110  1434        83   346        80   1088        120
# 111   794        61   345        61    449         70
# 112  1133        80   478        98    655         97
# 113  1191        92   922       130    269        111
# 114  1041        68   583        96    458        106
# 115  1917        79   462        99   1455        124
# 116  1448        50  1133        84    315         76
# 117  1964        57  1536        85    428         84
# 118   685        44   350        57    335         59
# 119   885        51   751        68    134         53
# 120  1312        54   992        94    320        100
# 121   638        74     0        12    638         74
# 122  3036       176   395       131   2641        223
# 123  1024        92    43        31    981         97
# 124   920        62   691        55    229         45
# 125   887        92   382        81    505        102
# 126  2413        99   614       148   1799        160
# 127  2618       111  2141       158    477        166
# 128  2898        79  1678       185   1220        202
# 129  2535       121   637       175   1898        202
# 130   984        49   746        82    238         83
# 131  1190        55   816       110    374        106
# 132  2376       115  1355       162   1021        192
# 133  2152       122  1727       143    425        136
# 134  1139        45   823        90    316         82
# 135  1980        82  1339       122    641        127
# 136  2124       109  1317       151    807        148
# 137  2308       126  2040       169    268        119
# 138  2639       154  1537       180   1102        212
# 139  1905        79  1272       138    633        128
# 140  1787        88   708       114   1079        129
# 141  1660        92   673       104    987        127
# 142  1392        96   791       119    601        119
# 143  1442       110   949       130    493        107
# 144  1801        63  1240       137    561        134
# 145  1345        88   989       125    356        113
# 146  1525        75     0        12   1525         75
# 147  1565        93     0        12   1565         93
# 148  1769       107   375        95   1394        134
# 149  1432        99   437        88    995        116
# 150  1618        91   708       114    910        134
# 151  1560        78   561        98    999        113
# 152  2036       105    84        47   1952        110
# 153  1166        74   465        90    701         89
# 154  2510       114  1154       206   1356        211
# 155    70        20    25        12     45         23
# 156    65        21     0        12     65         21
# 157     0        12     0        12      0         12
# 158   274        60    83        28    191         54
# 159   164        40   103        30     61         34
# 160   148        52    17        13    131         50
# 161     0        12     0        12      0         12
# 162  1852        89   717       107   1135        116
# 163  1577        81   685        93    892        112
# 164   961        77   202        41    759         87
# 165  4794       260  1524       273   3270        333
# 166  1491       104   721        97    770         98
# 167  1008        56   155        43    853         68
# 168  2789        98   665       169   2124        176
# 169   699        48     9        11    690         48
# 170  2155       124   120        68   2035        135
# 171  2433       138   734       126   1699        142
# 172  2266       151   269       135   1997        183
# 173  2667       172   179        95   2488        209
# 174  1983       151   401       113   1582        145
# 175  2569       149    65        54   2504        155
# 176  2105       122   443       128   1662        166
# 177  2423       148  1067       165   1356        190
# 178  1921       117   925       106    996        109
# 179  1606       110   299        78   1307        122
# 180   965        67   307        49    658         73
# 181  2340       134   680       158   1660        173
# 182  3126       181   529       165   2597        209
# 183  1390        50   530        98    860        103
# 184  2208        72   557       169   1651        174
# 185  1335        78   919       107    416         99
# 186  1792        72   599        89   1193        108
# 187  2384       168   779       147   1605        165
# 188  1269        59    23        24   1246         63
# 189  1822        85  1172       132    650        136
# 190  1929        98   404        78   1525        123
# 191  1249       107   721       115    528        133
# 192  2193       143  1046       106   1147        146
# 193  2403       153  1585       171    818        175
# 194  1962        59  1224       131    738        133
# 195  2475       103  1401       191   1074        202
# 196  2149       160   476       104   1673        141
#
#                                                   NAME state county   tract
# 0    Census Tract 260.04, San Francisco County, Cal...    06    075  026004
# 1    Census Tract 301.01, San Francisco County, Cal...    06    075  030101
# 2    Census Tract 330, San Francisco County, Califo...    06    075  033000
# 3    Census Tract 254.03, San Francisco County, Cal...    06    075  025403
# 4    Census Tract 264.01, San Francisco County, Cal...    06    075  026401
# 5    Census Tract 302.02, San Francisco County, Cal...    06    075  030202
# 6    Census Tract 353, San Francisco County, Califo...    06    075  035300
# 7    Census Tract 476, San Francisco County, Califo...    06    075  047600
# 8    Census Tract 106, San Francisco County, Califo...    06    075  010600
# 9    Census Tract 610, San Francisco County, Califo...    06    075  061000
# 10   Census Tract 203, San Francisco County, Califo...    06    075  020300
# 11   Census Tract 207, San Francisco County, Califo...    06    075  020700
# 12   Census Tract 208, San Francisco County, Califo...    06    075  020800
# 13   Census Tract 211, San Francisco County, Califo...    06    075  021100
# 14   Census Tract 212, San Francisco County, Califo...    06    075  021200
# 15   Census Tract 213, San Francisco County, Califo...    06    075  021300
# 16   Census Tract 107, San Francisco County, Califo...    06    075  010700
# 17   Census Tract 162, San Francisco County, Califo...    06    075  016200
# 18   Census Tract 169, San Francisco County, Califo...    06    075  016900
# 19   Census Tract 252, San Francisco County, Califo...    06    075  025200
# 20   Census Tract 101, San Francisco County, Califo...    06    075  010100
# 21   Census Tract 112, San Francisco County, Califo...    06    075  011200
# 22   Census Tract 134, San Francisco County, Califo...    06    075  013400
# 23   Census Tract 151, San Francisco County, Califo...    06    075  015100
# 24   Census Tract 157, San Francisco County, Califo...    06    075  015700
# 25   Census Tract 164, San Francisco County, Califo...    06    075  016400
# 26   Census Tract 615, San Francisco County, Califo...    06    075  061500
# 27   Census Tract 156, San Francisco County, Califo...    06    075  015600
# 28   Census Tract 102, San Francisco County, Califo...    06    075  010200
# 29   Census Tract 108, San Francisco County, Califo...    06    075  010800
# 30   Census Tract 331, San Francisco County, Califo...    06    075  033100
# 31   Census Tract 402, San Francisco County, Califo...    06    075  040200
# 32   Census Tract 103, San Francisco County, Califo...    06    075  010300
# 33   Census Tract 110, San Francisco County, Califo...    06    075  011000
# 34   Census Tract 154, San Francisco County, Califo...    06    075  015400
# 35   Census Tract 104, San Francisco County, Califo...    06    075  010400
# 36   Census Tract 255, San Francisco County, Califo...    06    075  025500
# 37   Census Tract 256, San Francisco County, Califo...    06    075  025600
# 38   Census Tract 258, San Francisco County, Califo...    06    075  025800
# 39   Census Tract 260.01, San Francisco County, Cal...    06    075  026001
# 40   Census Tract 451, San Francisco County, Califo...    06    075  045100
# 41   Census Tract 452, San Francisco County, Califo...    06    075  045200
# 42   Census Tract 261, San Francisco County, Califo...    06    075  026100
# 43   Census Tract 233, San Francisco County, Califo...    06    075  023300
# 44   Census Tract 253, San Francisco County, Califo...    06    075  025300
# 45   Census Tract 254.01, San Francisco County, Cal...    06    075  025401
# 46   Census Tract 263.01, San Francisco County, Cal...    06    075  026301
# 47   Census Tract 263.02, San Francisco County, Cal...    06    075  026302
# 48   Census Tract 263.03, San Francisco County, Cal...    06    075  026303
# 49   Census Tract 305, San Francisco County, Califo...    06    075  030500
# 50   Census Tract 311, San Francisco County, Califo...    06    075  031100
# 51   Census Tract 178.02, San Francisco County, Cal...    06    075  017802
# 52   Census Tract 204.01, San Francisco County, Cal...    06    075  020401
# 53   Census Tract 204.02, San Francisco County, Cal...    06    075  020402
# 54   Census Tract 227.04, San Francisco County, Cal...    06    075  022704
# 55   Census Tract 257.01, San Francisco County, Cal...    06    075  025701
# 56   Census Tract 257.02, San Francisco County, Cal...    06    075  025702
# 57   Census Tract 312.01, San Francisco County, Cal...    06    075  031201
# 58   Census Tract 312.02, San Francisco County, Cal...    06    075  031202
# 59   Census Tract 313.01, San Francisco County, Cal...    06    075  031301
# 60   Census Tract 119.01, San Francisco County, Cal...    06    075  011901
# 61   Census Tract 119.02, San Francisco County, Cal...    06    075  011902
# 62   Census Tract 122.01, San Francisco County, Cal...    06    075  012201
# 63   Census Tract 122.02, San Francisco County, Cal...    06    075  012202
# 64   Census Tract 123.01, San Francisco County, Cal...    06    075  012301
# 65   Census Tract 123.02, San Francisco County, Cal...    06    075  012302
# 66   Census Tract 124.01, San Francisco County, Cal...    06    075  012401
# 67   Census Tract 124.02, San Francisco County, Cal...    06    075  012402
# 68   Census Tract 125.01, San Francisco County, Cal...    06    075  012501
# 69   Census Tract 125.02, San Francisco County, Cal...    06    075  012502
# 70   Census Tract 126.01, San Francisco County, Cal...    06    075  012601
# 71   Census Tract 126.02, San Francisco County, Cal...    06    075  012602
# 72   Census Tract 129.01, San Francisco County, Cal...    06    075  012901
# 73   Census Tract 129.02, San Francisco County, Cal...    06    075  012902
# 74   Census Tract 131.01, San Francisco County, Cal...    06    075  013101
# 75   Census Tract 131.02, San Francisco County, Cal...    06    075  013102
# 76   Census Tract 158.01, San Francisco County, Cal...    06    075  015801
# 77   Census Tract 158.02, San Francisco County, Cal...    06    075  015802
# 78   Census Tract 168.01, San Francisco County, Cal...    06    075  016801
# 79   Census Tract 168.02, San Francisco County, Cal...    06    075  016802
# 80   Census Tract 171.01, San Francisco County, Cal...    06    075  017101
# 81   Census Tract 171.02, San Francisco County, Cal...    06    075  017102
# 82   Census Tract 178.01, San Francisco County, Cal...    06    075  017801
# 83   Census Tract 160, San Francisco County, Califo...    06    075  016000
# 84   Census Tract 105, San Francisco County, Califo...    06    075  010500
# 85   Census Tract 113, San Francisco County, Califo...    06    075  011300
# 86   Census Tract 152, San Francisco County, Califo...    06    075  015200
# 87   Census Tract 177, San Francisco County, Califo...    06    075  017700
# 88   Census Tract 227.02, San Francisco County, Cal...    06    075  022702
# 89   Census Tract 228.01, San Francisco County, Cal...    06    075  022801
# 90   Census Tract 231.03, San Francisco County, Cal...    06    075  023103
# 91   Census Tract 259, San Francisco County, Califo...    06    075  025900
# 92   Census Tract 260.03, San Francisco County, Cal...    06    075  026003
# 93   Census Tract 176.01, San Francisco County, Cal...    06    075  017601
# 94   Census Tract 201, San Francisco County, Califo...    06    075  020100
# 95   Census Tract 206, San Francisco County, Califo...    06    075  020600
# 96   Census Tract 209, San Francisco County, Califo...    06    075  020900
# 97   Census Tract 218, San Francisco County, Califo...    06    075  021800
# 98   Census Tract 226, San Francisco County, Califo...    06    075  022600
# 99   Census Tract 231.02, San Francisco County, Cal...    06    075  023102
# 100  Census Tract 251, San Francisco County, Califo...    06    075  025100
# 101  Census Tract 170, San Francisco County, Califo...    06    075  017000
# 102  Census Tract 180, San Francisco County, Califo...    06    075  018000
# 103  Census Tract 215, San Francisco County, Califo...    06    075  021500
# 104  Census Tract 228.03, San Francisco County, Cal...    06    075  022803
# 105  Census Tract 166, San Francisco County, Califo...    06    075  016600
# 106  Census Tract 179.02, San Francisco County, Cal...    06    075  017902
# 107  Census Tract 214, San Francisco County, Califo...    06    075  021400
# 108  Census Tract 217, San Francisco County, Califo...    06    075  021700
# 109  Census Tract 228.02, San Francisco County, Cal...    06    075  022802
# 110  Census Tract 229.01, San Francisco County, Cal...    06    075  022901
# 111  Census Tract 229.02, San Francisco County, Cal...    06    075  022902
# 112  Census Tract 229.03, San Francisco County, Cal...    06    075  022903
# 113  Census Tract 230.03, San Francisco County, Cal...    06    075  023003
# 114  Census Tract 264.03, San Francisco County, Cal...    06    075  026403
# 115  Census Tract 302.01, San Francisco County, Cal...    06    075  030201
# 116  Census Tract 303.02, San Francisco County, Cal...    06    075  030302
# 117  Census Tract 304, San Francisco County, Califo...    06    075  030400
# 118  Census Tract 264.04, San Francisco County, Cal...    06    075  026404
# 119  Census Tract 306, San Francisco County, Califo...    06    075  030600
# 120  Census Tract 310, San Francisco County, Califo...    06    075  031000
# 121  Census Tract 332.01, San Francisco County, Cal...    06    075  033201
# 122  Census Tract 111, San Francisco County, Califo...    06    075  011100
# 123  Census Tract 117, San Francisco County, Califo...    06    075  011700
# 124  Census Tract 428, San Francisco County, Califo...    06    075  042800
# 125  Census Tract 234, San Francisco County, Califo...    06    075  023400
# 126  Census Tract 165, San Francisco County, Califo...    06    075  016500
# 127  Census Tract 307, San Francisco County, Califo...    06    075  030700
# 128  Census Tract 351, San Francisco County, Califo...    06    075  035100
# 129  Census Tract 130, San Francisco County, Califo...    06    075  013000
# 130  Census Tract 260.02, San Francisco County, Cal...    06    075  026002
# 131  Census Tract 264.02, San Francisco County, Cal...    06    075  026402
# 132  Census Tract 303.01, San Francisco County, Cal...    06    075  030301
# 133  Census Tract 308, San Francisco County, Califo...    06    075  030800
# 134  Census Tract 254.02, San Francisco County, Cal...    06    075  025402
# 135  Census Tract 262, San Francisco County, Califo...    06    075  026200
# 136  Census Tract 216, San Francisco County, Califo...    06    075  021600
# 137  Census Tract 309, San Francisco County, Califo...    06    075  030900
# 138  Census Tract 479.01, San Francisco County, Cal...    06    075  047901
# 139  Census Tract 313.02, San Francisco County, Cal...    06    075  031302
# 140  Census Tract 326.01, San Francisco County, Cal...    06    075  032601
# 141  Census Tract 326.02, San Francisco County, Cal...    06    075  032602
# 142  Census Tract 328.01, San Francisco County, Cal...    06    075  032801
# 143  Census Tract 328.02, San Francisco County, Cal...    06    075  032802
# 144  Census Tract 329.01, San Francisco County, Cal...    06    075  032901
# 145  Census Tract 329.02, San Francisco County, Cal...    06    075  032902
# 146  Census Tract 332.03, San Francisco County, Cal...    06    075  033203
# 147  Census Tract 332.04, San Francisco County, Cal...    06    075  033204
# 148  Census Tract 426.01, San Francisco County, Cal...    06    075  042601
# 149  Census Tract 426.02, San Francisco County, Cal...    06    075  042602
# 150  Census Tract 478.01, San Francisco County, Cal...    06    075  047801
# 151  Census Tract 478.02, San Francisco County, Cal...    06    075  047802
# 152  Census Tract 611, San Francisco County, Califo...    06    075  061100
# 153  Census Tract 612, San Francisco County, Califo...    06    075  061200
# 154  Census Tract 614, San Francisco County, Califo...    06    075  061400
# 155  Census Tract 9802, San Francisco County, Calif...    06    075  980200
# 156  Census Tract 9803, San Francisco County, Calif...    06    075  980300
# 157  Census Tract 9804.01, San Francisco County, Ca...    06    075  980401
# 158  Census Tract 9805.01, San Francisco County, Ca...    06    075  980501
# 159  Census Tract 9806, San Francisco County, Calif...    06    075  980600
# 160  Census Tract 9809, San Francisco County, Calif...    06    075  980900
# 161  Census Tract 9901, San Francisco County, Calif...    06    075  990100
# 162  Census Tract 477.01, San Francisco County, Cal...    06    075  047701
# 163  Census Tract 477.02, San Francisco County, Cal...    06    075  047702
# 164  Census Tract 605.02, San Francisco County, Cal...    06    075  060502
# 165  Census Tract 607, San Francisco County, Califo...    06    075  060700
# 166  Census Tract 479.02, San Francisco County, Cal...    06    075  047902
# 167  Census Tract 604, San Francisco County, Califo...    06    075  060400
# 168  Census Tract 109, San Francisco County, Califo...    06    075  010900
# 169  Census Tract 118, San Francisco County, Califo...    06    075  011800
# 170  Census Tract 121, San Francisco County, Califo...    06    075  012100
# 171  Census Tract 128, San Francisco County, Califo...    06    075  012800
# 172  Census Tract 155, San Francisco County, Califo...    06    075  015500
# 173  Census Tract 161, San Francisco County, Califo...    06    075  016100
# 174  Census Tract 163, San Francisco County, Califo...    06    075  016300
# 175  Census Tract 120, San Francisco County, Califo...    06    075  012000
# 176  Census Tract 127, San Francisco County, Califo...    06    075  012700
# 177  Census Tract 132, San Francisco County, Califo...    06    075  013200
# 178  Census Tract 133, San Francisco County, Califo...    06    075  013300
# 179  Census Tract 135, San Francisco County, Califo...    06    075  013500
# 180  Census Tract 153, San Francisco County, Califo...    06    075  015300
# 181  Census Tract 167, San Francisco County, Califo...    06    075  016700
# 182  Census Tract 202, San Francisco County, Califo...    06    075  020200
# 183  Census Tract 205, San Francisco County, Califo...    06    075  020500
# 184  Census Tract 210, San Francisco County, Califo...    06    075  021000
# 185  Census Tract 230.01, San Francisco County, Cal...    06    075  023001
# 186  Census Tract 352.02, San Francisco County, Cal...    06    075  035202
# 187  Census Tract 427, San Francisco County, Califo...    06    075  042700
# 188  Census Tract 601, San Francisco County, Califo...    06    075  060100
# 189  Census Tract 314, San Francisco County, Califo...    06    075  031400
# 190  Census Tract 401, San Francisco County, Califo...    06    075  040100
# 191  Census Tract 232, San Francisco County, Califo...    06    075  023200
# 192  Census Tract 301.02, San Francisco County, Cal...    06    075  030102
# 193  Census Tract 327, San Francisco County, Califo...    06    075  032700
# 194  Census Tract 352.01, San Francisco County, Cal...    06    075  035201
# 195  Census Tract 354, San Francisco County, Califo...    06    075  035400
# 196  Census Tract 159, San Francisco County, Califo...    06    075  015900

# %%
renters_per_tract_2019 = get_ACS(2019)
renters_2019=pd.DataFrame(renters_per_tract_2019[1:], columns=renters_per_tract_2019[0] #first argument specified rows, second specifies columns
                         ).rename(columns={"GEO_ID":"geo_id",
                                           "B25003_001E":"total",
                                           "B25003_001M":"total_moe", #moe is margin of error
                                           "B25003_002E":"owner",
                                           "B25003_002M":"owner_moe",
                                           "B25003_003E":"renter",
                                          "B25003_003M":"renter_moe"} #these readable column names came from investigating the chart on data.census.gov
                                 ).drop(columns=['B25003_001EA', 
                                                 'B25003_001MA', 
                                                 'B25003_002EA',
                                                 'B25003_002MA',
                                                 'B25003_003EA',
                                                 'B25003_003MA',
                                                 'geo_id',]
                                       )

# %% [markdown]
# ### 3. Merge dataframes from steps one and two, resulting in two new dataframes: merged_2015 and merged_2019
#
# * merged_2015 = Census tracts in SF and 2015 estimates of renters
# * merged_2019 = Census tracts in SF and 2019 estimates of renters
#
# Before I can do the merge, I should see if there are any discrepancies between the data I got from SF Data (which is every tract in SF and its corresponding neighborhood) and the data I got from the API (which shows the number of renters in each tract).

# %%
renter_tracts = set(renters_2015['tract'].unique())
tract_file_tracts = set(tracts_file['tract'].unique())
renter_tracts - tract_file_tracts #figure out where those tracts went from sf data
# Out:
# {'980401', '990100'}

# %% [markdown]
# #### Ok so these two tracts are in the Census data but not in the SF data.
#
# ##### I looked up the above census tracts that are in the renter_tracts dataframe but not in the tract_files dataframe on Census Reporter, and it looks like they have a population of 0. So I feel comfortable moving on with my analysis. These tracts will be dropped when I do the merge.
# * 980401: https://censusreporter.org/profiles/14000US06075980401-census-tract-980401-san-francisco-ca/
# * 990100: https://censusreporter.org/profiles/14000US06075990100-census-tract-9901-san-francisco-ca/

# %%
merged_2015 = pd.merge(tracts_file,renters_2015,on='tract')

# %%
merged_2015.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 196 entries, 0 to 195
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   neighborhoods  196 non-null    object
#  1   tract          196 non-null    object
#  2   total          196 non-null    object
#  3   total_moe      196 non-null    object
#  4   owner          196 non-null    object
#  5   owner_moe      196 non-null    object
#  6   renter         196 non-null    int64
#  7   renter_moe     196 non-null    object
#  8   NAME           196 non-null    object
#  9   state          196 non-null    object
#  10  county         196 non-null    object
# dtypes: int64(1), object(10)
# memory usage: 18.4+ KB

# %%
merged_2015
# Out:
#                       neighborhoods   tract total total_moe owner owner_moe  \
# 0             Bayview Hunters Point  061200  1166        74   465        90
# 1             Bayview Hunters Point  023003  1191        92   922       130
# 2             Bayview Hunters Point  023001  1335        78   919       107
# 3             Bayview Hunters Point  023400   887        92   382        81
# 4             Bayview Hunters Point  023300   905        86   590        70
# 5             Bayview Hunters Point  023102  1547        82   520        85
# 6             Bayview Hunters Point  023103  1039        92    62        39
# 7             Bayview Hunters Point  023200  1249       107   721       115
# 8             Bayview Hunters Point  061000  1545       101   934       116
# 9             Bayview Hunters Point  980600   164        40   103        30
# 10            Bayview Hunters Point  980900   148        52    17        13
# 11            Bayview Hunters Point  980900   148        52    17        13
# 12                   Bernal Heights  025401  1244        95   566       100
# 13                   Bernal Heights  025200  2155       138  1351       189
# 14                   Bernal Heights  025402  1139        45   823        90
# 15                   Bernal Heights  025403  1533       106   782        95
# 16                   Bernal Heights  025300  1786       101   673       104
# 17                   Bernal Heights  025100  1340        62   982        87
# 18              Castro/Upper Market  020300  1716        89   475        87
# 19              Castro/Upper Market  016900  1600       105   390        82
# 20              Castro/Upper Market  020401  1667       104   897       125
# 21              Castro/Upper Market  020600  2578       153  1049       192
# 22              Castro/Upper Market  020500  1390        50   530        98
# 23              Castro/Upper Market  017000  2071       145  1142       148
# 24                        Chinatown  011300  1517        98   181        60
# 25                        Chinatown  010700  2426       144   200        80
# 26                        Chinatown  011800   699        48     9        11
# 27                        Chinatown  061100  2036       105    84        47
# 28                        Excelsior  026303  1244        74   735       111
# 29                        Excelsior  026004  1240        72   680       110
# 30                        Excelsior  026302  1521        62   933       126
# 31                        Excelsior  026003  1398        65   892       132
# 32                        Excelsior  026301  1377        47   778        96
# 33                        Excelsior  026001  1506        91   809       102
# 34                        Excelsior  026002   984        49   746        82
# 35                        Excelsior  025600  1626        81  1188       132
# 36   Financial District/South Beach  011700  1024        92    43        31
# 37   Financial District/South Beach  010500  1582       145   371        79
# 38   Financial District/South Beach  061500  7177       512  2729       514
# 39                        Glen Park  021800  1868        59  1090       139
# 40                        Glen Park  021700  1843        82  1219       135
# 41                 Golden Gate Park  980300    65        21     0        12
# 42                   Haight Ashbury  016600  2427       166   502       128
# 43                   Haight Ashbury  017102  1712        76   561        90
# 44                   Haight Ashbury  017101  1814        85   659        87
# 45                   Haight Ashbury  016700  2340       134   680       158
# 46                     Hayes Valley  016400  1887        79   326        96
# 47                     Hayes Valley  016802  1595       174   323        98
# 48                     Hayes Valley  016200  1647        94   166        61
# 49                     Hayes Valley  016300  1983       151   401       113
# 50                     Hayes Valley  016801  1639       121   296       119
# 51                   Inner Richmond  045200  2928       111  1011       178
# 52                   Inner Richmond  040200  2464       118   711       167
# 53                   Inner Richmond  040100  1929        98   404        78
# 54                   Inner Richmond  045100  2165       144   726       135
# 55                     Inner Sunset  030302  1448        50  1133        84
# 56                     Inner Sunset  030301  2376       115  1355       162
# 57                     Inner Sunset  030102  2193       143  1046       106
# 58                     Inner Sunset  030101  2096       108   593       126
# 59                     Inner Sunset  030202  2109       133   459       112
# 60                     Inner Sunset  030201  1917        79   462        99
# 61                        Japantown  015500  2266       151   269       135
# 62                        Lakeshore  033204  1565        93     0        12
# 63                        Lakeshore  033203  1525        75     0        12
# 64                        Lakeshore  033201   638        74     0        12
# 65                        Lakeshore  060400  1008        56   155        43
# 66                     Lincoln Park  980200    70        20    25        12
# 67                Lone Mountain/USF  016500  2413        99   614       148
# 68                Lone Mountain/USF  015700  2632       151   710       156
# 69                Lone Mountain/USF  015600  1432        91   328        79
# 70                           Marina  012601  1503       109   217        60
# 71                           Marina  012902  2084       130   550       170
# 72                           Marina  013000  2535       121   637       175
# 73                           Marina  012800  2433       138   734       126
# 74                           Marina  012901  1473       117   378        92
# 75                           Marina  012700  2105       122   443       128
# 76                           Marina  012602  1712        83   377        91
# 77                     McLaren Park  980501   274        60    83        28
# 78                          Mission  020700  2756       160   666       146
# 79                          Mission  020900  1823        98   250        70
# 80                          Mission  020100  2910       227   597       138
# 81                          Mission  022903  1133        80   478        98
# 82                          Mission  022802   639        51   166        45
# 83                          Mission  022901  1434        83   346        80
# 84                          Mission  022801  1939        94   802       105
# 85                          Mission  021000  2208        72   557       169
# 86                          Mission  020800  2663       125   414       135
# 87                          Mission  020200  3126       181   529       165
# 88                          Mission  017700   756        53   116        52
# 89                          Mission  022902   794        61   345        61
# 90                          Mission  022803  1610        86   552       111
# 91                      Mission Bay  060700  4794       260  1524       273
# 92                         Nob Hill  012100  2155       124   120        68
# 93                         Nob Hill  012000  2569       149    65        54
# 94                         Nob Hill  011200  1818       142   545       115
# 95                         Nob Hill  011100  3036       176   395       131
# 96                         Nob Hill  010800  2524       137   432       108
# 97                         Nob Hill  011902  1837       104   101        51
# 98                         Nob Hill  011901  1509       120   359        84
# 99                       Noe Valley  021400  1665        91   891        95
# 100                      Noe Valley  021300  1198        81   702       104
# 101                      Noe Valley  021100  1879        95   832       132
# 102                      Noe Valley  021600  2124       109  1317       151
# 103                      Noe Valley  021500  2580       133  1137       188
# 104                      Noe Valley  021200  1406        71   754       122
# 105                     North Beach  010600  1872       126   236        94
# 106                     North Beach  010400  2557       183   795       159
# 107                     North Beach  010100  2049       114   346        97
# 108      Oceanview/Merced/Ingleside  031301  1312        81  1040       112
# 109      Oceanview/Merced/Ingleside  031202   885        50   587        60
# 110      Oceanview/Merced/Ingleside  031302  1905        79  1272       138
# 111      Oceanview/Merced/Ingleside  031400  1822        85  1172       132
# 112      Oceanview/Merced/Ingleside  031201  1891        92  1137       119
# 113                   Outer Mission  026200  1980        82  1339       122
# 114                   Outer Mission  026100  2000        68  1107       128
# 115                   Outer Mission  025500  2734        58  2005       202
# 116                  Outer Richmond  047802  1560        78   561        98
# 117                  Outer Richmond  042601  1769       107   375        95
# 118                  Outer Richmond  047801  1618        91   708       114
# 119                  Outer Richmond  042602  1432        99   437        88
# 120                  Outer Richmond  047902  1491       104   721        97
# 121                  Outer Richmond  047702  1577        81   685        93
# 122                  Outer Richmond  047600  2197       116   673       153
# 123                  Outer Richmond  042700  2384       168   779       147
# 124                  Outer Richmond  047901  2639       154  1537       180
# 125                  Outer Richmond  047701  1852        89   717       107
# 126                 Pacific Heights  015300   965        67   307        49
# 127                 Pacific Heights  013400  2079       105   650       159
# 128                 Pacific Heights  013200  2423       148  1067       165
# 129                 Pacific Heights  013102  1668        85   338        86
# 130                 Pacific Heights  015200  2491       126   601       147
# 131                 Pacific Heights  013500  1606       110   299        78
# 132                 Pacific Heights  013101  2474       125   457       138
# 133                         Portola  025900  1478        60  1046       130
# 134                         Portola  025800   632        38   344        54
# 135                         Portola  025702  1149       119   581       124
# 136                         Portola  025701  1410        80  1002       106
# 137                    Potrero Hill  022704  1591       101   817       109
# 138                    Potrero Hill  061400  2510       114  1154       206
# 139                    Potrero Hill  022702  1011        55   359        73
# 140                    Potrero Hill  022600   868        68   432        61
# 141                        Presidio  060100  1269        59    23        24
# 142                Presidio Heights  015400  2874       158   826       153
# 143                Presidio Heights  013300  1921       117   925       106
# 144                    Russian Hill  010900  2789        98   665       169
# 145                    Russian Hill  011000  2617       129   473       211
# 146                    Russian Hill  010300  2030       171   507       136
# 147                    Russian Hill  010200  2615       171   826       175
# 148                        Seacliff  042800   920        62   691        55
# 149                 South of Market  017802  2156       168   464       143
# 150                 South of Market  017801  2248       142   418       100
# 151                 South of Market  018000  1342       116   613       103
# 152                 South of Market  017601  4107       287   431       131
# 153                 Sunset/Parkside  032902  1345        88   989       125
# 154                 Sunset/Parkside  032901  1801        63  1240       137
# 155                 Sunset/Parkside  032801  1392        96   791       119
# 156                 Sunset/Parkside  032802  1442       110   949       130
# 157                 Sunset/Parkside  032602  1660        92   673       104
# 158                 Sunset/Parkside  032601  1787        88   708       114
# 159                 Sunset/Parkside  033000  2689       112  1549       203
# 160                 Sunset/Parkside  035400  2475       103  1401       191
# 161                 Sunset/Parkside  035201  1962        59  1224       131
# 162                 Sunset/Parkside  035100  2898        79  1678       185
# 163                 Sunset/Parkside  033100  1492        56  1276        93
# 164                 Sunset/Parkside  035300  2589        69  1777       189
# 165                 Sunset/Parkside  035202  1792        72   599        89
# 166                 Sunset/Parkside  032700  2403       153  1585       171
# 167                      Tenderloin  012502  2229       133    20        32
# 168                      Tenderloin  012302  1796       139     9        13
# 169                      Tenderloin  012301  1300       140     9        14
# 170                      Tenderloin  012401  2548       213     0        12
# 171                      Tenderloin  012201  2931       121   110        61
# 172                      Tenderloin  012202  1616       103    37        18
# 173                      Tenderloin  012501  2272       194    73        54
# 174                      Tenderloin  012402  2252       165   202       122
# 175                 Treasure Island  017902   624        88     0        12
# 176                      Twin Peaks  030500  1008        63   740        78
# 177                      Twin Peaks  020402  2625        99   618       160
# 178               Visitacion Valley  060502   961        77   202        41
# 179               Visitacion Valley  026403  1041        68   583        96
# 180               Visitacion Valley  026401  1062        57   723        82
# 181               Visitacion Valley  026402  1190        55   816       110
# 182               Visitacion Valley  026404   685        44   350        57
# 183              West of Twin Peaks  031100  2462       129  1542       171
# 184              West of Twin Peaks  031000  1312        54   992        94
# 185              West of Twin Peaks  030900  2308       126  2040       169
# 186              West of Twin Peaks  030700  2618       111  2141       158
# 187              West of Twin Peaks  030600   885        51   751        68
# 188              West of Twin Peaks  030800  2152       122  1727       143
# 189              West of Twin Peaks  030400  1964        57  1536        85
# 190                Western Addition  016100  2667       172   179        95
# 191                Western Addition  015900  2149       160   476       104
# 192                Western Addition  015100  1500       133   355        82
# 193                Western Addition  015802  1542       108   256        85
# 194                Western Addition  016000  1639       132   473        98
# 195                Western Addition  015801  1703       104   446       102
#
#      renter renter_moe                                               NAME  \
# 0       701         89  Census Tract 612, San Francisco County, Califo...
# 1       269        111  Census Tract 230.03, San Francisco County, Cal...
# 2       416         99  Census Tract 230.01, San Francisco County, Cal...
# 3       505        102  Census Tract 234, San Francisco County, Califo...
# 4       315         93  Census Tract 233, San Francisco County, Califo...
# 5      1027        120  Census Tract 231.02, San Francisco County, Cal...
# 6       977         94  Census Tract 231.03, San Francisco County, Cal...
# 7       528        133  Census Tract 232, San Francisco County, Califo...
# 8       611        126  Census Tract 610, San Francisco County, Califo...
# 9        61         34  Census Tract 9806, San Francisco County, Calif...
# 10      131         50  Census Tract 9809, San Francisco County, Calif...
# 11      131         50  Census Tract 9809, San Francisco County, Calif...
# 12      678        120  Census Tract 254.01, San Francisco County, Cal...
# 13      804        188  Census Tract 252, San Francisco County, Califo...
# 14      316         82  Census Tract 254.02, San Francisco County, Cal...
# 15      751        133  Census Tract 254.03, San Francisco County, Cal...
# 16     1113        140  Census Tract 253, San Francisco County, Califo...
# 17      358         82  Census Tract 251, San Francisco County, Califo...
# 18     1241        108  Census Tract 203, San Francisco County, Califo...
# 19     1210        116  Census Tract 169, San Francisco County, Califo...
# 20      770        147  Census Tract 204.01, San Francisco County, Cal...
# 21     1529        220  Census Tract 206, San Francisco County, Califo...
# 22      860        103  Census Tract 205, San Francisco County, Califo...
# 23      929        164  Census Tract 170, San Francisco County, Califo...
# 24     1336        106  Census Tract 113, San Francisco County, Califo...
# 25     2226        158  Census Tract 107, San Francisco County, Califo...
# 26      690         48  Census Tract 118, San Francisco County, Califo...
# 27     1952        110  Census Tract 611, San Francisco County, Califo...
# 28      509        106  Census Tract 263.03, San Francisco County, Cal...
# 29      560        131  Census Tract 260.04, San Francisco County, Cal...
# 30      588        120  Census Tract 263.02, San Francisco County, Cal...
# 31      506        123  Census Tract 260.03, San Francisco County, Cal...
# 32      599         93  Census Tract 263.01, San Francisco County, Cal...
# 33      697        120  Census Tract 260.01, San Francisco County, Cal...
# 34      238         83  Census Tract 260.02, San Francisco County, Cal...
# 35      438        105  Census Tract 256, San Francisco County, Califo...
# 36      981         97  Census Tract 117, San Francisco County, Califo...
# 37     1211        121  Census Tract 105, San Francisco County, Califo...
# 38     4448        531  Census Tract 615, San Francisco County, Califo...
# 39      778        119  Census Tract 218, San Francisco County, Califo...
# 40      624        129  Census Tract 217, San Francisco County, Califo...
# 41       65         21  Census Tract 9803, San Francisco County, Calif...
# 42     1925        202  Census Tract 166, San Francisco County, Califo...
# 43     1151        114  Census Tract 171.02, San Francisco County, Cal...
# 44     1155        112  Census Tract 171.01, San Francisco County, Cal...
# 45     1660        173  Census Tract 167, San Francisco County, Califo...
# 46     1561        121  Census Tract 164, San Francisco County, Califo...
# 47     1272        162  Census Tract 168.02, San Francisco County, Cal...
# 48     1481        110  Census Tract 162, San Francisco County, Califo...
# 49     1582        145  Census Tract 163, San Francisco County, Califo...
# 50     1343        123  Census Tract 168.01, San Francisco County, Cal...
# 51     1917        174  Census Tract 452, San Francisco County, Califo...
# 52     1753        174  Census Tract 402, San Francisco County, Califo...
# 53     1525        123  Census Tract 401, San Francisco County, Califo...
# 54     1439        178  Census Tract 451, San Francisco County, Califo...
# 55      315         76  Census Tract 303.02, San Francisco County, Cal...
# 56     1021        192  Census Tract 303.01, San Francisco County, Cal...
# 57     1147        146  Census Tract 301.02, San Francisco County, Cal...
# 58     1503        158  Census Tract 301.01, San Francisco County, Cal...
# 59     1650        144  Census Tract 302.02, San Francisco County, Cal...
# 60     1455        124  Census Tract 302.01, San Francisco County, Cal...
# 61     1997        183  Census Tract 155, San Francisco County, Califo...
# 62     1565         93  Census Tract 332.04, San Francisco County, Cal...
# 63     1525         75  Census Tract 332.03, San Francisco County, Cal...
# 64      638         74  Census Tract 332.01, San Francisco County, Cal...
# 65      853         68  Census Tract 604, San Francisco County, Califo...
# 66       45         23  Census Tract 9802, San Francisco County, Calif...
# 67     1799        160  Census Tract 165, San Francisco County, Califo...
# 68     1922        217  Census Tract 157, San Francisco County, Califo...
# 69     1104         94  Census Tract 156, San Francisco County, Califo...
# 70     1286        123  Census Tract 126.01, San Francisco County, Cal...
# 71     1534        189  Census Tract 129.02, San Francisco County, Cal...
# 72     1898        202  Census Tract 130, San Francisco County, Califo...
# 73     1699        142  Census Tract 128, San Francisco County, Califo...
# 74     1095        135  Census Tract 129.01, San Francisco County, Cal...
# 75     1662        166  Census Tract 127, San Francisco County, Califo...
# 76     1335        101  Census Tract 126.02, San Francisco County, Cal...
# 77      191         54  Census Tract 9805.01, San Francisco County, Ca...
# 78     2090        192  Census Tract 207, San Francisco County, Califo...
# 79     1573        100  Census Tract 209, San Francisco County, Califo...
# 80     2313        266  Census Tract 201, San Francisco County, Califo...
# 81      655         97  Census Tract 229.03, San Francisco County, Cal...
# 82      473         56  Census Tract 228.02, San Francisco County, Cal...
# 83     1088        120  Census Tract 229.01, San Francisco County, Cal...
# 84     1137        124  Census Tract 228.01, San Francisco County, Cal...
# 85     1651        174  Census Tract 210, San Francisco County, Califo...
# 86     2249        192  Census Tract 208, San Francisco County, Califo...
# 87     2597        209  Census Tract 202, San Francisco County, Califo...
# 88      640         73  Census Tract 177, San Francisco County, Califo...
# 89      449         70  Census Tract 229.02, San Francisco County, Cal...
# 90     1058        117  Census Tract 228.03, San Francisco County, Cal...
# 91     3270        333  Census Tract 607, San Francisco County, Califo...
# 92     2035        135  Census Tract 121, San Francisco County, Califo...
# 93     2504        155  Census Tract 120, San Francisco County, Califo...
# 94     1273        141  Census Tract 112, San Francisco County, Califo...
# 95     2641        223  Census Tract 111, San Francisco County, Califo...
# 96     2092        159  Census Tract 108, San Francisco County, Califo...
# 97     1736        109  Census Tract 119.02, San Francisco County, Cal...
# 98     1150        133  Census Tract 119.01, San Francisco County, Cal...
# 99      774        117  Census Tract 214, San Francisco County, Califo...
# 100     496        103  Census Tract 213, San Francisco County, Califo...
# 101    1047        137  Census Tract 211, San Francisco County, Califo...
# 102     807        148  Census Tract 216, San Francisco County, Califo...
# 103    1443        191  Census Tract 215, San Francisco County, Califo...
# 104     652        123  Census Tract 212, San Francisco County, Califo...
# 105    1636        134  Census Tract 106, San Francisco County, Califo...
# 106    1762        239  Census Tract 104, San Francisco County, Califo...
# 107    1703        141  Census Tract 101, San Francisco County, Califo...
# 108     272         91  Census Tract 313.01, San Francisco County, Cal...
# 109     298         62  Census Tract 312.02, San Francisco County, Cal...
# 110     633        128  Census Tract 313.02, San Francisco County, Cal...
# 111     650        136  Census Tract 314, San Francisco County, Califo...
# 112     754        116  Census Tract 312.01, San Francisco County, Cal...
# 113     641        127  Census Tract 262, San Francisco County, Califo...
# 114     893        123  Census Tract 261, San Francisco County, Califo...
# 115     729        214  Census Tract 255, San Francisco County, Califo...
# 116     999        113  Census Tract 478.02, San Francisco County, Cal...
# 117    1394        134  Census Tract 426.01, San Francisco County, Cal...
# 118     910        134  Census Tract 478.01, San Francisco County, Cal...
# 119     995        116  Census Tract 426.02, San Francisco County, Cal...
# 120     770         98  Census Tract 479.02, San Francisco County, Cal...
# 121     892        112  Census Tract 477.02, San Francisco County, Cal...
# 122    1524        173  Census Tract 476, San Francisco County, Califo...
# 123    1605        165  Census Tract 427, San Francisco County, Califo...
# 124    1102        212  Census Tract 479.01, San Francisco County, Cal...
# 125    1135        116  Census Tract 477.01, San Francisco County, Cal...
# 126     658         73  Census Tract 153, San Francisco County, Califo...
# 127    1429        170  Census Tract 134, San Francisco County, Califo...
# 128    1356        190  Census Tract 132, San Francisco County, Califo...
# 129    1330        117  Census Tract 131.02, San Francisco County, Cal...
# 130    1890        176  Census Tract 152, San Francisco County, Califo...
# 131    1307        122  Census Tract 135, San Francisco County, Califo...
# 132    2017        166  Census Tract 131.01, San Francisco County, Cal...
# 133     432        130  Census Tract 259, San Francisco County, Califo...
# 134     288         53  Census Tract 258, San Francisco County, Califo...
# 135     568        110  Census Tract 257.02, San Francisco County, Cal...
# 136     408        105  Census Tract 257.01, San Francisco County, Cal...
# 137     774        127  Census Tract 227.04, San Francisco County, Cal...
# 138    1356        211  Census Tract 614, San Francisco County, Califo...
# 139     652         80  Census Tract 227.02, San Francisco County, Cal...
# 140     436         73  Census Tract 226, San Francisco County, Califo...
# 141    1246         63  Census Tract 601, San Francisco County, Califo...
# 142    2048        214  Census Tract 154, San Francisco County, Califo...
# 143     996        109  Census Tract 133, San Francisco County, Califo...
# 144    2124        176  Census Tract 109, San Francisco County, Califo...
# 145    2144        213  Census Tract 110, San Francisco County, Califo...
# 146    1523        183  Census Tract 103, San Francisco County, Califo...
# 147    1789        202  Census Tract 102, San Francisco County, Califo...
# 148     229         45  Census Tract 428, San Francisco County, Califo...
# 149    1692        214  Census Tract 178.02, San Francisco County, Cal...
# 150    1830        149  Census Tract 178.01, San Francisco County, Cal...
# 151     729        122  Census Tract 180, San Francisco County, Califo...
# 152    3676        306  Census Tract 176.01, San Francisco County, Cal...
# 153     356        113  Census Tract 329.02, San Francisco County, Cal...
# 154     561        134  Census Tract 329.01, San Francisco County, Cal...
# 155     601        119  Census Tract 328.01, San Francisco County, Cal...
# 156     493        107  Census Tract 328.02, San Francisco County, Cal...
# 157     987        127  Census Tract 326.02, San Francisco County, Cal...
# 158    1079        129  Census Tract 326.01, San Francisco County, Cal...
# 159    1140        212  Census Tract 330, San Francisco County, Califo...
# 160    1074        202  Census Tract 354, San Francisco County, Califo...
# 161     738        133  Census Tract 352.01, San Francisco County, Cal...
# 162    1220        202  Census Tract 351, San Francisco County, Califo...
# 163     216         80  Census Tract 331, San Francisco County, Califo...
# 164     812        185  Census Tract 353, San Francisco County, Califo...
# 165    1193        108  Census Tract 352.02, San Francisco County, Cal...
# 166     818        175  Census Tract 327, San Francisco County, Califo...
# 167    2209        135  Census Tract 125.02, San Francisco County, Cal...
# 168    1787        140  Census Tract 123.02, San Francisco County, Cal...
# 169    1291        141  Census Tract 123.01, San Francisco County, Cal...
# 170    2548        213  Census Tract 124.01, San Francisco County, Cal...
# 171    2821        132  Census Tract 122.01, San Francisco County, Cal...
# 172    1579        106  Census Tract 122.02, San Francisco County, Cal...
# 173    2199        211  Census Tract 125.01, San Francisco County, Cal...
# 174    2050        190  Census Tract 124.02, San Francisco County, Cal...
# 175     624         88  Census Tract 179.02, San Francisco County, Cal...
# 176     268         79  Census Tract 305, San Francisco County, Califo...
# 177    2007        176  Census Tract 204.02, San Francisco County, Cal...
# 178     759         87  Census Tract 605.02, San Francisco County, Cal...
# 179     458        106  Census Tract 264.03, San Francisco County, Cal...
# 180     339         93  Census Tract 264.01, San Francisco County, Cal...
# 181     374        106  Census Tract 264.02, San Francisco County, Cal...
# 182     335         59  Census Tract 264.04, San Francisco County, Cal...
# 183     920        168  Census Tract 311, San Francisco County, Califo...
# 184     320        100  Census Tract 310, San Francisco County, Califo...
# 185     268        119  Census Tract 309, San Francisco County, Califo...
# 186     477        166  Census Tract 307, San Francisco County, Califo...
# 187     134         53  Census Tract 306, San Francisco County, Califo...
# 188     425        136  Census Tract 308, San Francisco County, Califo...
# 189     428         84  Census Tract 304, San Francisco County, Califo...
# 190    2488        209  Census Tract 161, San Francisco County, Califo...
# 191    1673        141  Census Tract 159, San Francisco County, Califo...
# 192    1145        139  Census Tract 151, San Francisco County, Califo...
# 193    1286        131  Census Tract 158.02, San Francisco County, Cal...
# 194    1166        123  Census Tract 160, San Francisco County, Califo...
# 195    1257        131  Census Tract 158.01, San Francisco County, Cal...
#
#     state county
# 0      06    075
# 1      06    075
# 2      06    075
# 3      06    075
# 4      06    075
# 5      06    075
# 6      06    075
# 7      06    075
# 8      06    075
# 9      06    075
# 10     06    075
# 11     06    075
# 12     06    075
# 13     06    075
# 14     06    075
# 15     06    075
# 16     06    075
# 17     06    075
# 18     06    075
# 19     06    075
# 20     06    075
# 21     06    075
# 22     06    075
# 23     06    075
# 24     06    075
# 25     06    075
# 26     06    075
# 27     06    075
# 28     06    075
# 29     06    075
# 30     06    075
# 31     06    075
# 32     06    075
# 33     06    075
# 34     06    075
# 35     06    075
# 36     06    075
# 37     06    075
# 38     06    075
# 39     06    075
# 40     06    075
# 41     06    075
# 42     06    075
# 43     06    075
# 44     06    075
# 45     06    075
# 46     06    075
# 47     06    075
# 48     06    075
# 49     06    075
# 50     06    075
# 51     06    075
# 52     06    075
# 53     06    075
# 54     06    075
# 55     06    075
# 56     06    075
# 57     06    075
# 58     06    075
# 59     06    075
# 60     06    075
# 61     06    075
# 62     06    075
# 63     06    075
# 64     06    075
# 65     06    075
# 66     06    075
# 67     06    075
# 68     06    075
# 69     06    075
# 70     06    075
# 71     06    075
# 72     06    075
# 73     06    075
# 74     06    075
# 75     06    075
# 76     06    075
# 77     06    075
# 78     06    075
# 79     06    075
# 80     06    075
# 81     06    075
# 82     06    075
# 83     06    075
# 84     06    075
# 85     06    075
# 86     06    075
# 87     06    075
# 88     06    075
# 89     06    075
# 90     06    075
# 91     06    075
# 92     06    075
# 93     06    075
# 94     06    075
# 95     06    075
# 96     06    075
# 97     06    075
# 98     06    075
# 99     06    075
# 100    06    075
# 101    06    075
# 102    06    075
# 103    06    075
# 104    06    075
# 105    06    075
# 106    06    075
# 107    06    075
# 108    06    075
# 109    06    075
# 110    06    075
# 111    06    075
# 112    06    075
# 113    06    075
# 114    06    075
# 115    06    075
# 116    06    075
# 117    06    075
# 118    06    075
# 119    06    075
# 120    06    075
# 121    06    075
# 122    06    075
# 123    06    075
# 124    06    075
# 125    06    075
# 126    06    075
# 127    06    075
# 128    06    075
# 129    06    075
# 130    06    075
# 131    06    075
# 132    06    075
# 133    06    075
# 134    06    075
# 135    06    075
# 136    06    075
# 137    06    075
# 138    06    075
# 139    06    075
# 140    06    075
# 141    06    075
# 142    06    075
# 143    06    075
# 144    06    075
# 145    06    075
# 146    06    075
# 147    06    075
# 148    06    075
# 149    06    075
# 150    06    075
# 151    06    075
# 152    06    075
# 153    06    075
# 154    06    075
# 155    06    075
# 156    06    075
# 157    06    075
# 158    06    075
# 159    06    075
# 160    06    075
# 161    06    075
# 162    06    075
# 163    06    075
# 164    06    075
# 165    06    075
# 166    06    075
# 167    06    075
# 168    06    075
# 169    06    075
# 170    06    075
# 171    06    075
# 172    06    075
# 173    06    075
# 174    06    075
# 175    06    075
# 176    06    075
# 177    06    075
# 178    06    075
# 179    06    075
# 180    06    075
# 181    06    075
# 182    06    075
# 183    06    075
# 184    06    075
# 185    06    075
# 186    06    075
# 187    06    075
# 188    06    075
# 189    06    075
# 190    06    075
# 191    06    075
# 192    06    075
# 193    06    075
# 194    06    075
# 195    06    075

# %% [markdown]
# I'll want to convert the renter column to an integer, because I plan on adding them up by neighborhood..

# %%
merged_2015['renter'] = merged_2015.renter.astype(int)

# %% [markdown]
# #### Gonna do the same process above for 2019 data.

# %%
renter_tracts = set(renters_2019['tract'].unique())
tract_file_tracts = set(tracts_file['tract'].unique())
renter_tracts - tract_file_tracts #figure out where those tracts went from sf data
# Out:
# {'980401', '990100'}

# %% [markdown]
# #### Same deal for 2019. Will proceed with the merge.

# %%
merged_2019 = pd.merge(tracts_file,renters_2019,on='tract')

# %%
merged_2019['renter'] = merged_2019.renter.astype(int)

# %% [markdown]
# ### 4. Add up renters by neighborhod in 2015 and 2019, and sum the complaints by neighborhood in 2015 and 2019 using my original dataframe
#
# #### Merged groupbys:
# * renters_2015_neighborhood = Sum of renters grouped by neighborhood in 2015
# * renters_2019_neighborhood = Sum of renters grouped by neighborhood in 2019
#
# #### Tenant_petitions groupbys:
# * grouped_complaints_in_2015 = Sum of complaints grouped by neighborhood in 2015
# * grouped_complaints_in_2019 = Sum of complaints grouped by neighborhood in 2019

# %%
renters_2015_neighborhood = merged_2015.groupby('neighborhoods').renter.sum().reset_index()

# %%
renters_2015_neighborhood
# Out:
#                      neighborhoods  renter
# 0            Bayview Hunters Point    5672
# 1                   Bernal Heights    4020
# 2              Castro/Upper Market    6539
# 3                        Chinatown    6204
# 4                        Excelsior    4135
# 5   Financial District/South Beach    6640
# 6                        Glen Park    1402
# 7                 Golden Gate Park      65
# 8                   Haight Ashbury    5891
# 9                     Hayes Valley    7239
# 10                  Inner Richmond    6634
# 11                    Inner Sunset    7091
# 12                       Japantown    1997
# 13                       Lakeshore    4581
# 14                    Lincoln Park      45
# 15               Lone Mountain/USF    4825
# 16                          Marina   10509
# 17                    McLaren Park     191
# 18                         Mission   17973
# 19                     Mission Bay    3270
# 20                        Nob Hill   13431
# 21                      Noe Valley    5219
# 22                     North Beach    5101
# 23      Oceanview/Merced/Ingleside    2607
# 24                   Outer Mission    2263
# 25                  Outer Richmond   11326
# 26                 Pacific Heights    9987
# 27                         Portola    1696
# 28                    Potrero Hill    3218
# 29                        Presidio    1246
# 30                Presidio Heights    3044
# 31                    Russian Hill    7580
# 32                        Seacliff     229
# 33                 South of Market    7927
# 34                 Sunset/Parkside   11288
# 35                      Tenderloin   16484
# 36                 Treasure Island     624
# 37                      Twin Peaks    2275
# 38               Visitacion Valley    2265
# 39              West of Twin Peaks    2972
# 40                Western Addition    9015

# %%
mask_2015_complaints = (tenant_petitions['year'] == 2015)
complaints_in_2015 = tenant_petitions.loc[mask_2015_complaints]

# %%
grouped_complaints_in_2015 = complaints_in_2015.groupby('neighborhoods').petition_id.count().reset_index()

# %%
grouped_complaints_in_2015
# Out:
#                      neighborhoods  petition_id
# 0            Bayview Hunters Point           64
# 1                   Bernal Heights           54
# 2              Castro/Upper Market           39
# 3                        Chinatown          157
# 4                        Excelsior           82
# 5   Financial District/South Beach           29
# 6                        Glen Park            7
# 7                 Golden Gate Park            6
# 8                   Haight Ashbury           46
# 9                     Hayes Valley           62
# 10                  Inner Richmond           34
# 11                    Inner Sunset           41
# 12                       Japantown            6
# 13                       Lakeshore           20
# 14                    Lincoln Park            2
# 15               Lone Mountain/USF           37
# 16                          Marina           49
# 17                    McLaren Park            4
# 18                         Mission          192
# 19                        Nob Hill           93
# 20                      Noe Valley           24
# 21                     North Beach           29
# 22      Oceanview/Merced/Ingleside           44
# 23                   Outer Mission           57
# 24                  Outer Richmond           81
# 25                 Pacific Heights           46
# 26                         Portola           24
# 27                    Potrero Hill           22
# 28                Presidio Heights           15
# 29                    Russian Hill           43
# 30                        Seacliff            1
# 31                 South of Market           32
# 32                 Sunset/Parkside          102
# 33                      Tenderloin          184
# 34                 Treasure Island            2
# 35                      Twin Peaks           15
# 36               Visitacion Valley           34
# 37              West of Twin Peaks           42
# 38                Western Addition           91

# %%
renters_2019_neighborhood = merged_2019.groupby('neighborhoods').renter.sum().reset_index()

# %%
mask_2019_complaints = (tenant_petitions['year'] == 2019)
complaints_in_2019 = tenant_petitions.loc[mask_2019_complaints]

# %%
grouped_complaints_in_2019 = complaints_in_2019.groupby('neighborhoods').petition_id.count().reset_index()

# %% [markdown]
# ### 5. Merge the groupby objects in step 4, and find rate of complaints per 100 renters in the neighborhood
# * **complaints_by_renters_2015** = renters_2015_neighborhood, which has the amount of renters per neighborhood in **2015**, and grouped_complaints_in_2015, which has the amount of complaints by neighborhood in **2015**
# * **complaints_by_renters_2019** = renters_2019_neighborhood, which has the amount of renters per neighborhood in **2019**, and grouped_complaints_in_2015, which has the amount of complaints by neighborhood in **2019**
#
# #### For each merged dataframe, I will create a column to calculate the rate of complaints for every 100 renters. I chose a rate of per 100 because some neighborhoods have fewer than 1,000 renters, according to the ACS data.

# %%
complaints_by_renters_2015 = pd.merge(renters_2015_neighborhood, grouped_complaints_in_2015, on='neighborhoods')

# %%
complaints_by_renters_2015['rate'] = ((complaints_by_renters_2015['petition_id']/complaints_by_renters_2015['renter'])*100).round(2)

# %%
complaints_by_renters_2015
# Out:
#                      neighborhoods  renter  petition_id  rate
# 0            Bayview Hunters Point    5672           64  1.13
# 1                   Bernal Heights    4020           54  1.34
# 2              Castro/Upper Market    6539           39  0.60
# 3                        Chinatown    6204          157  2.53
# 4                        Excelsior    4135           82  1.98
# 5   Financial District/South Beach    6640           29  0.44
# 6                        Glen Park    1402            7  0.50
# 7                 Golden Gate Park      65            6  9.23
# 8                   Haight Ashbury    5891           46  0.78
# 9                     Hayes Valley    7239           62  0.86
# 10                  Inner Richmond    6634           34  0.51
# 11                    Inner Sunset    7091           41  0.58
# 12                       Japantown    1997            6  0.30
# 13                       Lakeshore    4581           20  0.44
# 14                    Lincoln Park      45            2  4.44
# 15               Lone Mountain/USF    4825           37  0.77
# 16                          Marina   10509           49  0.47
# 17                    McLaren Park     191            4  2.09
# 18                         Mission   17973          192  1.07
# 19                        Nob Hill   13431           93  0.69
# 20                      Noe Valley    5219           24  0.46
# 21                     North Beach    5101           29  0.57
# 22      Oceanview/Merced/Ingleside    2607           44  1.69
# 23                   Outer Mission    2263           57  2.52
# 24                  Outer Richmond   11326           81  0.72
# 25                 Pacific Heights    9987           46  0.46
# 26                         Portola    1696           24  1.42
# 27                    Potrero Hill    3218           22  0.68
# 28                Presidio Heights    3044           15  0.49
# 29                    Russian Hill    7580           43  0.57
# 30                        Seacliff     229            1  0.44
# 31                 South of Market    7927           32  0.40
# 32                 Sunset/Parkside   11288          102  0.90
# 33                      Tenderloin   16484          184  1.12
# 34                 Treasure Island     624            2  0.32
# 35                      Twin Peaks    2275           15  0.66
# 36               Visitacion Valley    2265           34  1.50
# 37              West of Twin Peaks    2972           42  1.41
# 38                Western Addition    9015           91  1.01

# %%
complaints_by_renters_2019 = pd.merge(renters_2019_neighborhood, grouped_complaints_in_2019, on='neighborhoods')
complaints_by_renters_2019['rate'] = ((complaints_by_renters_2019['petition_id']/complaints_by_renters_2019['renter'])*100).round(2)

# %%
complaints_by_renters_2019
# Out:
#                      neighborhoods  renter  petition_id  rate
# 0            Bayview Hunters Point    5849           33  0.56
# 1                   Bernal Heights    3888           38  0.98
# 2              Castro/Upper Market    6901           78  1.13
# 3                        Chinatown    6486           59  0.91
# 4                        Excelsior    3587           40  1.12
# 5   Financial District/South Beach    7656            9  0.12
# 6                        Glen Park    1201            2  0.17
# 7                 Golden Gate Park      48            2  4.17
# 8                   Haight Ashbury    5562           59  1.06
# 9                     Hayes Valley    7696           60  0.78
# 10                  Inner Richmond    6040           40  0.66
# 11                    Inner Sunset    6961           41  0.59
# 12                       Japantown    1963            2  0.10
# 13                       Lakeshore    4671           11  0.24
# 14                    Lincoln Park      26            1  3.85
# 15               Lone Mountain/USF    4348           32  0.74
# 16                          Marina   10123           42  0.41
# 17                         Mission   17832          145  0.81
# 18                        Nob Hill   13156           76  0.58
# 19                      Noe Valley    5083           39  0.77
# 20                     North Beach    4966           36  0.72
# 21      Oceanview/Merced/Ingleside    2419           22  0.91
# 22                   Outer Mission    2372           36  1.52
# 23                  Outer Richmond   11218           58  0.52
# 24                 Pacific Heights    9413           33  0.35
# 25                         Portola    1630           15  0.92
# 26                    Potrero Hill    3690            9  0.24
# 27                Presidio Heights    2982           18  0.60
# 28                    Russian Hill    7252           57  0.79
# 29                        Seacliff     220            4  1.82
# 30                 South of Market   10540           29  0.28
# 31                 Sunset/Parkside   10466           62  0.59
# 32                      Tenderloin   17199          104  0.60
# 33                      Twin Peaks    2084           17  0.82
# 34               Visitacion Valley    2405           19  0.79
# 35              West of Twin Peaks    3026           21  0.69
# 36                Western Addition    9031           34  0.38

# %%
alt.Chart(complaints_by_renters_2015).mark_circle(size=60).encode(
    x=alt.X('petition_id',title='Amount of Complaints'),
    y=alt.Y('rate',title='Complaints for Every 100 Renters'),
    tooltip=['neighborhoods', 'rate', 'petition_id']
).properties(
    title='Complaints by Neighborhood in 2015',
    width=800,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %%
alt.Chart(complaints_by_renters_2019).mark_circle(size=60).encode(
    x=alt.X('petition_id',title='Amount of Complaints'),
    y=alt.Y('rate',title='Complaints for Every 100 Renters'),
    tooltip=['neighborhoods', 'rate', 'petition_id']
).properties(
    title='Amount of Complaints by Neighborhood in 2019',
    width=800,
    height=300
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ### Finding 3 (cont.):
# * In 2015, Golden Gate Park had the most complaints per 100 renters. However, the number of complaints from that neighborhood in that year was only 9. What's more interesting is that in Chinatown, which had the third highest amount of complaints in 2015, had a rate of 2.5 complaints per 100 renters. The rate of complaints per 100 renters in Chinatown *decreased* in 2019 to less than one (but keep in mind that the number of complaints in 2019 was lower than in 2015).
# * The main finding here is that none of the neighborhoods with a high number of complaints stick out. They all have relatively low rates of complaints per 100 renters.

# %% [markdown]
# ## Conclusion 😅
#
# **Findings**
#
# Since 2010, tenants filed the most complaints in 2014 and 2015. This correlates with an increase in rent that the city hadn't seen before. Complaints overall decreased to their lowest levels in 2020 and 2021, coinciding with the pandemic and increased housing protections. However, complaints alleging that the landlord decreased housing services stayed relatively stable, while the number of all complaints decreased over time. This could be related to the fact that more people were home and perhaps noticed or demanded more housing services. Overall, most of the tenant complaints since 2010 came from the Mission, but when normalized for the number of renters there in 2015 and 2019, Mission didn't stand out.
#
# **Further analysis/reporting**
#
# I'd be interested in seeing complaints/number of renters for each year in this interval. Is there a year where a neighborhood with a high number of complaints stood out for its rate? Are the complaints all similar? Do they all come from a specific building?
#
# Why did the number of housing services complaints stay steady when the overall number of complaints decreased? How did the rent board handle these complaints, and what was the outcome? Did tenants win lower rents for what they saw as decreased housing services? I'd be especially interested in focusing on housing service complaints that occurred during the pandemic, since, as mentioned before, people were more home for longer periods of time.
#
# Are the trends similar for complaints from landlords? Do landlord complaints rise in 2015 and decrease after?
